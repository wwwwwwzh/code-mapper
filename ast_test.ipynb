# %%
import ast
import os
import importlib.util
from pathlib import Path
import ast as std_ast
import os
from pathlib import Path
import warnings


class ExternalCallCleaner(std_ast.NodeTransformer):
    def __init__(self, external_calls):
        super().__init__()
        self.external_calls = external_calls
    
    def generic_visit(self, node):
        if node in self.external_calls:
            return None
        return super().generic_visit(node)

def clean_ast(tree, external_calls):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        cleaner = ExternalCallCleaner(external_calls)
        return cleaner.visit(tree)

def build_project_ast(root_dir):
    project_modules = get_project_modules(root_dir)
    full_ast = {}
    
    for py_file in Path(root_dir).rglob('*.py'):
        with open(py_file, 'r', encoding='utf-8') as f:
            code = f.read()
        
        try:
            tree = std_ast.parse(code)
            visitor = ExternalCallVisitor(project_modules)
            visitor.visit(tree)
            cleaned_tree = clean_ast(tree, visitor.external_calls)
            full_ast[str(py_file)] = cleaned_tree
        except SyntaxError:
            continue
    
    return full_ast

class ExternalCallVisitor(ast.NodeVisitor):
    def __init__(self, project_modules):
        self.project_modules = project_modules
        self.external_calls = []
        self.current_imports = set()

    def visit_Import(self, node):
        for alias in node.names:
            module_name = alias.name.split('.')[0]
            if not self._is_project_module(module_name):
                self.current_imports.add(module_name)
        self.generic_visit(node)

    def visit_ImportFrom(self, node):
        module_name = node.module.split('.')[0] if node.module else ''
        if not self._is_project_module(module_name):
            self.current_imports.add(module_name)
        self.generic_visit(node)

    def visit_Call(self, node):
        if isinstance(node.func, ast.Attribute):
            module_name = self._get_call_module(node.func)
        elif isinstance(node.func, ast.Name):
            module_name = node.func.id
        else:
            module_name = None

        if module_name and module_name in self.current_imports:
            self.external_calls.append(node)
        
        self.generic_visit(node)

    def _is_project_module(self, module_name):
        return any(module_name in pm for pm in self.project_modules)

    def _get_call_module(self, node):
        if isinstance(node.value, ast.Name):
            return node.value.id
        elif isinstance(node.value, ast.Attribute):
            return self._get_call_module(node.value)
        return None

def get_project_modules(root_dir):
    modules = set()
    for path in Path(root_dir).rglob('*.py'): # For all python files
        if '__init__.py' in str(path):
            package = str(path.parent).replace(os.sep, '.')
            modules.add(package)
        if path.stem != '__init__':
            module_name = str(path).replace(os.sep, '.')[:-3]
            modules.add(module_name)
    return modules

def clean_ast(node, bad_nodes):
    if isinstance(node, ast.AST):
        new_node = type(node)(**{
            k: clean_ast(v, bad_nodes)
            for k, v in ast.iter_fields(node)
            if k not in ['body', 'orelse', 'finalbody']
        })
        for field in ['body', 'orelse', 'finalbody']:
            if hasattr(node, field):
                new_body = []
                for child in getattr(node, field):
                    cleaned = clean_ast(child, bad_nodes)
                    if cleaned not in bad_nodes and cleaned is not None:
                        new_body.append(cleaned)
                setattr(new_node, field, new_body)
        return new_node
    elif isinstance(node, list):
        return [clean_ast(child, bad_nodes) for child in node 
                if child not in bad_nodes]
    else:
        return node

def build_project_ast(root_dir):
    project_modules = get_project_modules(root_dir)
    full_ast = {}
    
    for py_file in Path(root_dir).rglob('*.py'): # for py files in root
        with open(py_file, 'r') as f:
            code = f.read()
        
        try:
            tree = ast.parse(code) 
            print(tree)
            visitor = ExternalCallVisitor(project_modules)
            visitor.visit(tree)
            cleaned_tree = clean_ast(tree, visitor.external_calls)
            full_ast[str(py_file)] = cleaned_tree
        except SyntaxError:
            continue
    
    return full_ast

# %%
import astpretty

def build_project_ast(root_dir):
    project_modules = get_project_modules(root_dir)
    full_ast = {}
    
    for py_file in Path(root_dir).rglob('*.py'): # for py files in root
        with open(py_file, 'r') as f:
            code = f.read()
        
        try:
            tree = ast.parse(code) 
            print(tree)
            # visitor = ExternalCallVisitor(project_modules)
            # visitor.visit(tree)
            # cleaned_tree = clean_ast(tree, visitor.external_calls)
            full_ast[str(py_file)] = tree
        except SyntaxError:
            continue
    
    return full_ast
# Usage
project_root = '/nas/longleaf/home/zhw/personal/code_mapper/repos/b27d2ab10f64'
codebase_ast = build_project_ast(project_root)

for file_path, file_ast in codebase_ast.items():
    print(f"File: {file_path}")
    astpretty.pprint(file_ast, show_offsets=False)
    print("\n" + "="*80 + "\n")
# Out:
# <ast.Module object at 0x7f8d4043ffd0>
# <ast.Module object at 0x7f8d4028bfd0>
# <ast.Module object at 0x7f8d402b7fd0>
# <ast.Module object at 0x7f8d4030bfd0>
# <ast.Module object at 0x7f8d401d3fd0>
# <ast.Module object at 0x7f8d4011fb50>
# <ast.Module object at 0x7f8d2ad62710>
# <ast.Module object at 0x7f8d2acbbfd0>
# <ast.Module object at 0x7f8d2abe7fd0>
# <ast.Module object at 0x7f8d2aa3ffd0>
# <ast.Module object at 0x7f8d2aa77fd0>
# <ast.Module object at 0x7f8d2aaa7fd0>
# <ast.Module object at 0x7f8d2a913fd0>
# <ast.Module object at 0x7f8d2a96ffd0>
# File: /nas/longleaf/home/zhw/personal/code_mapper/repos/b27d2ab10f64/Q_Slerp.py
# Module(
#     body=[
#         Import(
#             names=[alias(name='numpy', asname='np')],
#         ),
#         ImportFrom(
#             module='numpy',
#             names=[alias(name='*', asname=None)],
#             level=0,
#         ),
#         ImportFrom(
#             module='math',
#             names=[
#                 alias(name='sqrt', asname=None),
#                 alias(name='sin', asname=None),
#                 alias(name='cos', asname=None),
#                 alias(name='acos', asname=None),
#                 alias(name='asin', asname=None),
#             ],
#             level=0,
#         ),
#         ClassDef(
#             name='quaternion',
#             bases=[],
#             keywords=[],
#             body=[
#                 Expr(
#                     value=Constant(value='A quaternion is a compact method of representing a 3D rotation that has\n    computational advantages including speed and numerical robustness.\n\n    A quaternion has 2 parts, a scalar s, and a vector v and is typically written::\n\n        q = s <vx vy vz>\n\n    A unit quaternion is one for which M{s^2+vx^2+vy^2+vz^2 = 1}.\n\n    A quaternion can be considered as a rotation about a vector in space where\n    q = cos (theta/2) sin(theta/2) <vx vy vz>\n    where <vx vy vz> is a unit vector.\n\n    Various functions such as INV, NORM, UNIT and PLOT are overloaded for\n    quaternion objects.\n\n    Arithmetic operators are also overloaded to allow quaternion multiplication,\n    division, exponentiaton, and quaternion-vector multiplication (rotation).\n    ', kind=None),
#                 ),
#                 FunctionDef(
#                     name='__init__',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[arg(arg='self', annotation=None, type_comment=None)],
#                         vararg=arg(arg='args', annotation=None, type_comment=None),
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Expr(
#                             value=Constant(value='\n        Constructor for quaternion objects:\n        - q = quaternion()                 object initialization\n        - q = quaternion(s, v1, v2, v3)    from 4 elements\n        ', kind=None),
#                         ),
#                         Assign(
#                             targets=[
#                                 Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='vec',
#                                     ctx=Store(),
#                                 ),
#                             ],
#                             value=List(elts=[], ctx=Load()),
#                             type_comment=None,
#                         ),
#                         If(
#                             test=Compare(
#                                 left=Call(
#                                     func=Name(id='len', ctx=Load()),
#                                     args=[Name(id='args', ctx=Load())],
#                                     keywords=[],
#                                 ),
#                                 ops=[Eq()],
#                                 comparators=[Constant(value=0, kind=None)],
#                             ),
#                             body=[
#                                 Assign(
#                                     targets=[
#                                         Attribute(
#                                             value=Name(id='self', ctx=Load()),
#                                             attr='s',
#                                             ctx=Store(),
#                                         ),
#                                     ],
#                                     value=Constant(value=1.0, kind=None),
#                                     type_comment=None,
#                                 ),
#                                 Assign(
#                                     targets=[
#                                         Attribute(
#                                             value=Name(id='self', ctx=Load()),
#                                             attr='v',
#                                             ctx=Store(),
#                                         ),
#                                     ],
#                                     value=Call(
#                                         func=Name(id='matrix', ctx=Load()),
#                                         args=[
#                                             List(
#                                                 elts=[
#                                                     Constant(value=0.0, kind=None),
#                                                     Constant(value=0.0, kind=None),
#                                                     Constant(value=0.0, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                         ],
#                                         keywords=[],
#                                     ),
#                                     type_comment=None,
#                                 ),
#                             ],
#                             orelse=[
#                                 If(
#                                     test=Compare(
#                                         left=Call(
#                                             func=Name(id='len', ctx=Load()),
#                                             args=[Name(id='args', ctx=Load())],
#                                             keywords=[],
#                                         ),
#                                         ops=[Eq()],
#                                         comparators=[Constant(value=4, kind=None)],
#                                     ),
#                                     body=[
#                                         Assign(
#                                             targets=[
#                                                 Attribute(
#                                                     value=Name(id='self', ctx=Load()),
#                                                     attr='s',
#                                                     ctx=Store(),
#                                                 ),
#                                             ],
#                                             value=Subscript(
#                                                 value=Name(id='args', ctx=Load()),
#                                                 slice=Constant(value=0, kind=None),
#                                                 ctx=Load(),
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                         Assign(
#                                             targets=[
#                                                 Attribute(
#                                                     value=Name(id='self', ctx=Load()),
#                                                     attr='v',
#                                                     ctx=Store(),
#                                                 ),
#                                             ],
#                                             value=Call(
#                                                 func=Name(id='mat', ctx=Load()),
#                                                 args=[
#                                                     Subscript(
#                                                         value=Name(id='args', ctx=Load()),
#                                                         slice=Slice(
#                                                             lower=Constant(value=1, kind=None),
#                                                             upper=Constant(value=4, kind=None),
#                                                             step=None,
#                                                         ),
#                                                         ctx=Load(),
#                                                     ),
#                                                 ],
#                                                 keywords=[],
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                     ],
#                                     orelse=[
#                                         Expr(
#                                             value=Call(
#                                                 func=Name(id='print', ctx=Load()),
#                                                 args=[Constant(value='error', kind=None)],
#                                                 keywords=[],
#                                             ),
#                                         ),
#                                         Return(
#                                             value=Constant(value=None, kind=None),
#                                         ),
#                                     ],
#                                 ),
#                             ],
#                         ),
#                     ],
#                     decorator_list=[],
#                     returns=None,
#                     type_comment=None,
#                     type_params=[],
#                 ),
#                 FunctionDef(
#                     name='__repr__',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[arg(arg='self', annotation=None, type_comment=None)],
#                         vararg=None,
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Return(
#                             value=BinOp(
#                                 left=Constant(value='%f <%f, %f, %f>', kind=None),
#                                 op=Mod(),
#                                 right=Tuple(
#                                     elts=[
#                                         Attribute(
#                                             value=Name(id='self', ctx=Load()),
#                                             attr='s',
#                                             ctx=Load(),
#                                         ),
#                                         Subscript(
#                                             value=Attribute(
#                                                 value=Name(id='self', ctx=Load()),
#                                                 attr='v',
#                                                 ctx=Load(),
#                                             ),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=0, kind=None),
#                                                     Constant(value=0, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                         Subscript(
#                                             value=Attribute(
#                                                 value=Name(id='self', ctx=Load()),
#                                                 attr='v',
#                                                 ctx=Load(),
#                                             ),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=0, kind=None),
#                                                     Constant(value=1, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                         Subscript(
#                                             value=Attribute(
#                                                 value=Name(id='self', ctx=Load()),
#                                                 attr='v',
#                                                 ctx=Load(),
#                                             ),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=0, kind=None),
#                                                     Constant(value=2, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                     ],
#                                     ctx=Load(),
#                                 ),
#                             ),
#                         ),
#                     ],
#                     decorator_list=[],
#                     returns=None,
#                     type_comment=None,
#                     type_params=[],
#                 ),
#                 FunctionDef(
#                     name='tr2q',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self', annotation=None, type_comment=None),
#                             arg(arg='t', annotation=None, type_comment=None),
#                         ],
#                         vararg=None,
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         kwarg=None,
#                         defaults=[],
#                     ),
#                     body=[
#                         Assign(
#                             targets=[Name(id='qs', ctx=Store())],
#                             value=BinOp(
#                                 left=Call(
#                                     func=Name(id='sqrt', ctx=Load()),
#                                     args=[
#                                         BinOp(
#                                             left=Call(
#                                                 func=Name(id='trace', ctx=Load()),
#                                                 args=[Name(id='t', ctx=Load())],
#                                                 keywords=[],
#                                             ),
#                                             op=Add(),
#                                             right=Constant(value=1, kind=None),
#                                         ),
#                                     ],
#                                     keywords=[],
#                                 ),
#                                 op=Div(),
#                                 right=Constant(value=2.0, kind=None),
#                             ),
#                             type_comment=None,
#                         ),
#                         Assign(
#                             targets=[Name(id='kx', ctx=Store())],
#                             value=BinOp(
#                                 left=Subscript(
#                                     value=Name(id='t', ctx=Load()),
#                                     slice=Tuple(
#                                         elts=[
#                                             Constant(value=2, kind=None),
#                                             Constant(value=1, kind=None),
#                                         ],
#                                         ctx=Load(),
#                                     ),
#                                     ctx=Load(),
#                                 ),
#                                 op=Sub(),
#                                 right=Subscript(
#                                     value=Name(id='t', ctx=Load()),
#                                     slice=Tuple(
#                                         elts=[
#                                             Constant(value=1, kind=None),
#                                             Constant(value=2, kind=None),
#                                         ],
#                                         ctx=Load(),
#                                     ),
#                                     ctx=Load(),
#                                 ),
#                             ),
#                             type_comment=None,
#                         ),
#                         Assign(
#                             targets=[Name(id='ky', ctx=Store())],
#                             value=BinOp(
#                                 left=Subscript(
#                                     value=Name(id='t', ctx=Load()),
#                                     slice=Tuple(
#                                         elts=[
#                                             Constant(value=0, kind=None),
#                                             Constant(value=2, kind=None),
#                                         ],
#                                         ctx=Load(),
#                                     ),
#                                     ctx=Load(),
#                                 ),
#                                 op=Sub(),
#                                 right=Subscript(
#                                     value=Name(id='t', ctx=Load()),
#                                     slice=Tuple(
#                                         elts=[
#                                             Constant(value=2, kind=None),
#                                             Constant(value=0, kind=None),
#                                         ],
#                                         ctx=Load(),
#                                     ),
#                                     ctx=Load(),
#                                 ),
#                             ),
#                             type_comment=None,
#                         ),
#                         Assign(
#                             targets=[Name(id='kz', ctx=Store())],
#                             value=BinOp(
#                                 left=Subscript(
#                                     value=Name(id='t', ctx=Load()),
#                                     slice=Tuple(
#                                         elts=[
#                                             Constant(value=1, kind=None),
#                                             Constant(value=0, kind=None),
#                                         ],
#                                         ctx=Load(),
#                                     ),
#                                     ctx=Load(),
#                                 ),
#                                 op=Sub(),
#                                 right=Subscript(
#                                     value=Name(id='t', ctx=Load()),
#                                     slice=Tuple(
#                                         elts=[
#                                             Constant(value=0, kind=None),
#                                             Constant(value=1, kind=None),
#                                         ],
#                                         ctx=Load(),
#                                     ),
#                                     ctx=Load(),
#                                 ),
#                             ),
#                             type_comment=None,
#                         ),
#                         If(
#                             test=BoolOp(
#                                 op=And(),
#                                 values=[
#                                     Compare(
#                                         left=Subscript(
#                                             value=Name(id='t', ctx=Load()),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=0, kind=None),
#                                                     Constant(value=0, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                         ops=[GtE()],
#                                         comparators=[
#                                             Subscript(
#                                                 value=Name(id='t', ctx=Load()),
#                                                 slice=Tuple(
#                                                     elts=[
#                                                         Constant(value=1, kind=None),
#                                                         Constant(value=1, kind=None),
#                                                     ],
#                                                     ctx=Load(),
#                                                 ),
#                                                 ctx=Load(),
#                                             ),
#                                         ],
#                                     ),
#                                     Compare(
#                                         left=Subscript(
#                                             value=Name(id='t', ctx=Load()),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=0, kind=None),
#                                                     Constant(value=0, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                         ops=[GtE()],
#                                         comparators=[
#                                             Subscript(
#                                                 value=Name(id='t', ctx=Load()),
#                                                 slice=Tuple(
#                                                     elts=[
#                                                         Constant(value=2, kind=None),
#                                                         Constant(value=2, kind=None),
#                                                     ],
#                                                     ctx=Load(),
#                                                 ),
#                                                 ctx=Load(),
#                                             ),
#                                         ],
#                                     ),
#                                 ],
#                             ),
#                             body=[
#                                 Assign(
#                                     targets=[Name(id='kx1', ctx=Store())],
#                                     value=BinOp(
#                                         left=BinOp(
#                                             left=BinOp(
#                                                 left=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=0, kind=None),
#                                                             Constant(value=0, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                                 op=Sub(),
#                                                 right=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=1, kind=None),
#                                                             Constant(value=1, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                             ),
#                                             op=Sub(),
#                                             right=Subscript(
#                                                 value=Name(id='t', ctx=Load()),
#                                                 slice=Tuple(
#                                                     elts=[
#                                                         Constant(value=2, kind=None),
#                                                         Constant(value=2, kind=None),
#                                                     ],
#                                                     ctx=Load(),
#                                                 ),
#                                                 ctx=Load(),
#                                             ),
#                                         ),
#                                         op=Add(),
#                                         right=Constant(value=1, kind=None),
#                                     ),
#                                     type_comment=None,
#                                 ),
#                                 Assign(
#                                     targets=[Name(id='ky1', ctx=Store())],
#                                     value=BinOp(
#                                         left=Subscript(
#                                             value=Name(id='t', ctx=Load()),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=1, kind=None),
#                                                     Constant(value=0, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                         op=Add(),
#                                         right=Subscript(
#                                             value=Name(id='t', ctx=Load()),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=0, kind=None),
#                                                     Constant(value=1, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                     ),
#                                     type_comment=None,
#                                 ),
#                                 Assign(
#                                     targets=[Name(id='kz1', ctx=Store())],
#                                     value=BinOp(
#                                         left=Subscript(
#                                             value=Name(id='t', ctx=Load()),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=2, kind=None),
#                                                     Constant(value=0, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                         op=Add(),
#                                         right=Subscript(
#                                             value=Name(id='t', ctx=Load()),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=0, kind=None),
#                                                     Constant(value=2, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                     ),
#                                     type_comment=None,
#                                 ),
#                                 Assign(
#                                     targets=[Name(id='add', ctx=Store())],
#                                     value=Compare(
#                                         left=Name(id='kx', ctx=Load()),
#                                         ops=[GtE()],
#                                         comparators=[Constant(value=0, kind=None)],
#                                     ),
#                                     type_comment=None,
#                                 ),
#                             ],
#                             orelse=[
#                                 If(
#                                     test=Compare(
#                                         left=Subscript(
#                                             value=Name(id='t', ctx=Load()),
#                                             slice=Tuple(
#                                                 elts=[
#                                                     Constant(value=1, kind=None),
#                                                     Constant(value=1, kind=None),
#                                                 ],
#                                                 ctx=Load(),
#                                             ),
#                                             ctx=Load(),
#                                         ),
#                                         ops=[GtE()],
#                                         comparators=[
#                                             Subscript(
#                                                 value=Name(id='t', ctx=Load()),
#                                                 slice=Tuple(
#                                                     elts=[
#                                                         Constant(value=2, kind=None),
#                                                         Constant(value=2, kind=None),
#                                                     ],
#                                                     ctx=Load(),
#                                                 ),
#                                                 ctx=Load(),
#                                             ),
#                                         ],
#                                     ),
#                                     body=[
#                                         Assign(
#                                             targets=[Name(id='kx1', ctx=Store())],
#                                             value=BinOp(
#                                                 left=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=1, kind=None),
#                                                             Constant(value=0, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                                 op=Add(),
#                                                 right=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=0, kind=None),
#                                                             Constant(value=1, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                         Assign(
#                                             targets=[Name(id='ky1', ctx=Store())],
#                                             value=BinOp(
#                                                 left=BinOp(
#                                                     left=BinOp(
#                                                         left=Subscript(
#                                                             value=Name(id='t', ctx=Load()),
#                                                             slice=Tuple(
#                                                                 elts=[
#                                                                     Constant(value=1, kind=None),
#                                                                     Constant(value=1, kind=None),
#                                                                 ],
#                                                                 ctx=Load(),
#                                                             ),
#                                                             ctx=Load(),
#                                                         ),
#                                                         op=Sub(),
#                                                         right=Subscript(
#                                                             value=Name(id='t', ctx=Load()),
#                                                             slice=Tuple(
#                                                                 elts=[
#                                                                     Constant(value=0, kind=None),
#                                                                     Constant(value=0, kind=None),
#                                                                 ],
#                                                                 ctx=Load(),
#                                                             ),
#                                                             ctx=Load(),
#                                                         ),
#                                                     ),
#                                                     op=Sub(),
#                                                     right=Subscript(
#                                                         value=Name(id='t', ctx=Load()),
#                                                         slice=Tuple(
#                                                             elts=[
#                                                                 Constant(value=2, kind=None),
#                                                                 Constant(value=2, kind=None),
#                                                             ],
#                                                             ctx=Load(),
#                                                         ),
#                                                         ctx=Load(),
#                                                     ),
#                                                 ),
#                                                 op=Add(),
#                                                 right=Constant(value=1, kind=None),
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                         Assign(
#                                             targets=[Name(id='kz1', ctx=Store())],
#                                             value=BinOp(
#                                                 left=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=2, kind=None),
#                                                             Constant(value=1, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                                 op=Add(),
#                                                 right=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=1, kind=None),
#                                                             Constant(value=2, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                         Assign(
#                                             targets=[Name(id='add', ctx=Store())],
#                                             value=Compare(
#                                                 left=Name(id='ky', ctx=Load()),
#                                                 ops=[GtE()],
#                                                 comparators=[Constant(value=0, kind=None)],
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                     ],
#                                     orelse=[
#                                         Assign(
#                                             targets=[Name(id='kx1', ctx=Store())],
#                                             value=BinOp(
#                                                 left=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=2, kind=None),
#                                                             Constant(value=0, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                                 op=Add(),
#                                                 right=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=0, kind=None),
#                                                             Constant(value=2, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                         Assign(
#                                             targets=[Name(id='ky1', ctx=Store())],
#                                             value=BinOp(
#                                                 left=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=2, kind=None),
#                                                             Constant(value=1, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                                 op=Add(),
#                                                 right=Subscript(
#                                                     value=Name(id='t', ctx=Load()),
#                                                     slice=Tuple(
#                                                         elts=[
#                                                             Constant(value=1, kind=None),
#                                                             Constant(value=2, kind=None),
#                                                         ],
#                                                         ctx=Load(),
#                                                     ),
#                                                     ctx=Load(),
#                                                 ),
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                         Assign(
#                                             targets=[Name(id='kz1', ctx=Store())],
#                                             value=BinOp(
#                                                 left=BinOp(
#                                                     left=BinOp(
#                                                         left=Subscript(
#                                                             value=Name(id='t', ctx=Load()),
#                                                             slice=Tuple(
#                                                                 elts=[
#                                                                     Constant(value=2, kind=None),
#                                                                     Constant(value=2, kind=None),
#                                                                 ],
#                                                                 ctx=Load(),
#                                                             ),
#                                                             ctx=Load(),
#                                                         ),
#                                                         op=Sub(),
#                                                         right=Subscript(
#                                                             value=Name(id='t', ctx=Load()),
#                                                             slice=Tuple(
#                                                                 elts=[
#                                                                     Constant(value=0, kind=None),
#                                                                     Constant(value=0, kind=None),
#                                                                 ],
#                                                                 ctx=Load(),
#                                                             ),
#                                                             ctx=Load(),
#                                                         ),
#                                                     ),
#                                                     op=Sub(),
#                                                     right=Subscript(
#                                                         value=Name(id='t', ctx=Load()),
#                                                         slice=Tuple(
#                                                             elts=[
#                                                                 Constant(value=1, kind=None),
#                                                                 Constant(value=1, kind=None),
#                                                             ],
#                                                             ctx=Load(),
#                                                         ),
#                                                         ctx=Load(),
#                                                     ),
#                                                 ),
#                                                 op=Add(),
#                                                 right=Constant(value=1, kind=None),
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                         Assign(
#                                             targets=[Name(id='add', ctx=Store())],
#                                             value=Compare(
#                                                 left=Name(id='kz', ctx=Load()),
#                                                 ops=[GtE()],
#                                                 comparators=[Constant(value=0, kind=None)],
#                                             ),
#                                             type_comment=None,
#                                         ),
#                                     ],
#                                 ),
#                             ],
#                         ),
#                         If(
# ...
#                                         Constant(value=2, kind=None),
#                                     ],
#                                     ctx=Load(),
#                                 ),
#                                 Call(
#                                     func=Attribute(
#                                         value=Name(id='np', ctx=Load()),
#                                         attr='argmax',
#                                         ctx=Load(),
#                                     ),
#                                     args=[Name(id='eigvals', ctx=Load())],
#                                     keywords=[],
#                                 ),
#                             ],
#                             ctx=Load(),
#                         ),
#                         ctx=Load(),
#                     ),
#                     type_comment=None,
#                 ),
#                 If(
#                     test=Compare(
#                         left=Subscript(
#                             value=Name(id='qvec', ctx=Load()),
#                             slice=Constant(value=0, kind=None),
#                             ctx=Load(),
#                         ),
#                         ops=[Lt()],
#                         comparators=[Constant(value=0, kind=None)],
#                     ),
#                     body=[
#                         AugAssign(
#                             target=Name(id='qvec', ctx=Store()),
#                             op=Mult(),
#                             value=UnaryOp(
#                                 op=USub(),
#                                 operand=Constant(value=1, kind=None),
#                             ),
#                         ),
#                     ],
#                     orelse=[],
#                 ),
#                 Return(
#                     value=Name(id='qvec', ctx=Load()),
#                 ),
#             ],
#             decorator_list=[],
#             returns=None,
#             type_comment=None,
#             type_params=[],
#         ),
#         FunctionDef(
#             name='linear_pose_interp',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[
#                     arg(arg='A_trans', annotation=None, type_comment=None),
#                     arg(arg='A_rot', annotation=None, type_comment=None),
#                     arg(arg='B_trans', annotation=None, type_comment=None),
#                     arg(arg='B_rot', annotation=None, type_comment=None),
#                     arg(arg='T', annotation=None, type_comment=None),
#                 ],
#                 vararg=None,
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 kwarg=None,
#                 defaults=[],
#             ),
#             body=[
#                 Expr(
#                     value=Constant(value='\n    Pose interpolator that calculates intermediate poses of a vector connecting 2 points\n    Interpolation is done linearly for both translation and rotation\n    Translation is done assuming that point A is rotationally invariant.\n    Rotation is done about the point A. Quaternion SLERP rotation is used to give the quickest rotation from A -> B\n    ** "Roll" or twisting of the arm is not taken into account in this calculation. Separate interpolations have to be done for the roll angle\n\n    Input:\n    Starting points start_A [X,Y,Z,roll,pitch,yaw] list\n    Ending points end_B in [X\',Y\',Z\',roll\',pitch\',yaw\'] list\n        Yaw, Pitch, Roll calculated in radians within bounds [0, 2*pi]\n        Sequence of rotation: Roll - 1st, Pitch - 2nd, Yaw - 3rd\n    T = no of intermediate poses\n\n    Output:\n    list of positions and rotations stored into the variable track\n        track is a dictionary with keys \'lin\' and \'rot\'\n\n    track[\'lin\'] - Linear interpolation of interval T of starting positions from A -> B\n    track[\'rot\'] - Slerp interpolation of quaternion of interval T, arranged as a list in [w x y z]\n    # track[\'rot\'] - Intermediate Yaw-Pitch-Roll poses of interval T, in sequence YPR\n\n    ', kind=None),
#                 ),
#                 Assign(
#                     targets=[Name(id='track', ctx=Store())],
#                     value=Dict(
#                         keys=[
#                             Constant(value='lin', kind=None),
#                             Constant(value='rot', kind=None),
#                         ],
#                         values=[
#                             List(elts=[], ctx=Load()),
#                             List(elts=[], ctx=Load()),
#                         ],
#                     ),
#                     type_comment=None,
#                 ),
#                 Assign(
#                     targets=[Name(id='q_a', ctx=Store())],
#                     value=Call(
#                         func=Name(id='rotmat2qvec', ctx=Load()),
#                         args=[Name(id='A_rot', ctx=Load())],
#                         keywords=[],
#                     ),
#                     type_comment=None,
#                 ),
#                 Assign(
#                     targets=[Name(id='q_b', ctx=Store())],
#                     value=Call(
#                         func=Name(id='rotmat2qvec', ctx=Load()),
#                         args=[Name(id='B_rot', ctx=Load())],
#                         keywords=[],
#                     ),
#                     type_comment=None,
#                 ),
#                 Assign(
#                     targets=[Name(id='QA', ctx=Store())],
#                     value=Call(
#                         func=Name(id='quaternion', ctx=Load()),
#                         args=[
#                             Subscript(
#                                 value=Name(id='q_a', ctx=Load()),
#                                 slice=Constant(value=0, kind=None),
#                                 ctx=Load(),
#                             ),
#                             Subscript(
#                                 value=Name(id='q_a', ctx=Load()),
#                                 slice=Constant(value=1, kind=None),
#                                 ctx=Load(),
#                             ),
#                             Subscript(
#                                 value=Name(id='q_a', ctx=Load()),
#                                 slice=Constant(value=2, kind=None),
#                                 ctx=Load(),
#                             ),
#                             Subscript(
#                                 value=Name(id='q_a', ctx=Load()),
#                                 slice=Constant(value=3, kind=None),
#                                 ctx=Load(),
#                             ),
#                         ],
#                         keywords=[],
#                     ),
#                     type_comment=None,
#                 ),
#                 Assign(
#                     targets=[Name(id='QB', ctx=Store())],
#                     value=Call(
#                         func=Name(id='quaternion', ctx=Load()),
#                         args=[
#                             Subscript(
#                                 value=Name(id='q_b', ctx=Load()),
#                                 slice=Constant(value=0, kind=None),
#                                 ctx=Load(),
#                             ),
#                             Subscript(
#                                 value=Name(id='q_b', ctx=Load()),
#                                 slice=Constant(value=1, kind=None),
#                                 ctx=Load(),
#                             ),
#                             Subscript(
#                                 value=Name(id='q_b', ctx=Load()),
#                                 slice=Constant(value=2, kind=None),
#                                 ctx=Load(),
#                             ),
#                             Subscript(
#                                 value=Name(id='q_b', ctx=Load()),
#                                 slice=Constant(value=3, kind=None),
#                                 ctx=Load(),
#                             ),
#                         ],
#                         keywords=[],
#                     ),
#                     type_comment=None,
#                 ),
#                 Assign(
#                     targets=[
#                         Subscript(
#                             value=Name(id='track', ctx=Load()),
#                             slice=Constant(value='lin', kind=None),
#                             ctx=Store(),
#                         ),
#                     ],
#                     value=Call(
#                         func=Attribute(
#                             value=Call(
#                                 func=Name(id='linear_translation', ctx=Load()),
#                                 args=[
#                                     Name(id='A_trans', ctx=Load()),
#                                     Name(id='B_trans', ctx=Load()),
#                                     Name(id='T', ctx=Load()),
#                                 ],
#                                 keywords=[],
#                             ),
#                             attr='tolist',
#                             ctx=Load(),
#                         ),
#                         args=[],
#                         keywords=[],
#                     ),
#                     type_comment=None,
#                 ),
#                 Assign(
#                     targets=[Name(id='q', ctx=Store())],
#                     value=Call(
#                         func=Name(id='interpolate', ctx=Load()),
#                         args=[
#                             Name(id='QA', ctx=Load()),
#                             Name(id='QB', ctx=Load()),
#                             Name(id='T', ctx=Load()),
#                         ],
#                         keywords=[],
#                     ),
#                     type_comment=None,
#                 ),
#                 Assign(
#                     targets=[
#                         Subscript(
#                             value=Name(id='track', ctx=Load()),
#                             slice=Constant(value='rot', kind=None),
#                             ctx=Store(),
#                         ),
#                     ],
#                     value=BinOp(
#                         left=List(
#                             elts=[
#                                 Attribute(
#                                     value=Name(id='q', ctx=Load()),
#                                     attr='s',
#                                     ctx=Load(),
#                                 ),
#                             ],
#                             ctx=Load(),
#                         ),
#                         op=Add(),
#                         right=Subscript(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Attribute(
#                                         value=Name(id='q', ctx=Load()),
#                                         attr='v',
#                                         ctx=Load(),
#                                     ),
#                                     attr='tolist',
#                                     ctx=Load(),
#                                 ),
#                                 args=[],
#                                 keywords=[],
#                             ),
#                             slice=Constant(value=0, kind=None),
#                             ctx=Load(),
#                         ),
#                     ),
#                     type_comment=None,
#                 ),
#                 Return(
#                     value=Tuple(
#                         elts=[
#                             Call(
#                                 func=Name(id='qvec2rotmat', ctx=Load()),
#                                 args=[
#                                     Subscript(
#                                         value=Name(id='track', ctx=Load()),
#                                         slice=Constant(value='rot', kind=None),
#                                         ctx=Load(),
#                                     ),
#                                 ],
#                                 keywords=[],
#                             ),
#                             Call(
#                                 func=Attribute(
#                                     value=Name(id='np', ctx=Load()),
#                                     attr='array',
#                                     ctx=Load(),
#                                 ),
#                                 args=[
#                                     Subscript(
#                                         value=Name(id='track', ctx=Load()),
#                                         slice=Constant(value='lin', kind=None),
#                                         ctx=Load(),
#                                     ),
#                                 ],
#                                 keywords=[],
#                             ),
#                         ],
#                         ctx=Load(),
#                     ),
#                 ),
#             ],
#             decorator_list=[],
#             returns=None,
#             type_comment=None,
#             type_params=[],
#         ),
#         If(
#             test=Compare(
#                 left=Name(id='__name__', ctx=Load()),
#                 ops=[Eq()],
#                 comparators=[Constant(value='__main__', kind=None)],
#             ),
#             body=[
#                 Assign(
#                     targets=[Name(id='A', ctx=Store())],
#                     value=List(
#                         elts=[
#                             Constant(value=0, kind=None),
#                             Constant(value=0, kind=None),
#                             Constant(value=0, kind=None),
#                             Constant(value=0, kind=None),
#                             Constant(value=0, kind=None),
#                             Constant(value=0, kind=None),
#                         ],
#                         ctx=Load(),
#                     ),
#                     type_comment=None,
#                 ),
#                 Assign(
#                     targets=[Name(id='B', ctx=Store())],
#                     value=List(
#                         elts=[
#                             Constant(value=1, kind=None),
#                             Constant(value=1, kind=None),
#                             Constant(value=1, kind=None),
#                             BinOp(
#                                 left=UnaryOp(
#                                     op=USub(),
#                                     operand=Name(id='pi', ctx=Load()),
#                                 ),
#                                 op=Div(),
#                                 right=Constant(value=2, kind=None),
#                             ),
#                             BinOp(
#                                 left=Name(id='pi', ctx=Load()),
#                                 op=Div(),
#                                 right=Constant(value=2, kind=None),
#                             ),
#                             BinOp(
#                                 left=UnaryOp(
#                                     op=USub(),
#                                     operand=Name(id='pi', ctx=Load()),
#                                 ),
#                                 op=Div(),
#                                 right=Constant(value=2, kind=None),
#                             ),
#                         ],
#                         ctx=Load(),
#                     ),
#                     type_comment=None,
#                 ),
#                 Assign(
#                     targets=[Name(id='track', ctx=Store())],
#                     value=Call(
#                         func=Name(id='linear_pose_interp', ctx=Load()),
#                         args=[
#                             Name(id='A', ctx=Load()),
#                             Name(id='B', ctx=Load()),
#                             Constant(value=1, kind=None),
#                         ],
#                         keywords=[],
#                     ),
#                     type_comment=None,
#                 ),
#             ],
#             orelse=[],
#         ),
#     ],
#     type_ignores=[],
# )
#
# ================================================================================
#
# File: /nas/longleaf/home/zhw/personal/code_mapper/repos/b27d2ab10f64/render_utils.py

# %%
# Usage
project_root = '/nas/longleaf/home/zhw/personal/code_mapper/repos/b27d2ab10f64'
codebase_ast = build_project_ast(project_root)
# Out:
# <ast.Module object at 0x7fd49c19bfd0>
# <ast.Module object at 0x7fd49473bfd0>
# /tmp/ipykernel_889175/3646978105.py:101: DeprecationWarning: IfExp.__init__ missing 1 required positional argument: 'body'. This will become an error in Python 3.15.
#   new_node = type(node)(**{
# /tmp/ipykernel_889175/3646978105.py:101: DeprecationWarning: IfExp.__init__ missing 1 required positional argument: 'orelse'. This will become an error in Python 3.15.
#   new_node = type(node)(**{
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Usage
#       2 project_root = '/nas/longleaf/home/zhw/personal/code_mapper/repos/b27d2ab10f64'
# ----> 3 codebase_ast = build_project_ast(project_root)
#
# Cell In[1], line 134, in build_project_ast(root_dir)
#     132     visitor = ExternalCallVisitor(project_modules)
#     133     visitor.visit(tree)
# --> 134     cleaned_tree = clean_ast(tree, visitor.external_calls)
#     135     full_ast[str(py_file)] = cleaned_tree
#     136 except SyntaxError:
#
# Cell In[1], line 110, in clean_ast(node, bad_nodes)
#     108 new_body = []
#     109 for child in getattr(node, field):
# --> 110     cleaned = clean_ast(child, bad_nodes)
#     111     if cleaned not in bad_nodes and cleaned is not None:
#     112         new_body.append(cleaned)
#
# Cell In[1], line 102, in clean_ast(node, bad_nodes)
#      99 def clean_ast(node, bad_nodes):
#     100     if isinstance(node, ast.AST):
#     101         new_node = type(node)(**{
# --> 102             k: clean_ast(v, bad_nodes)
#     103             for k, v in ast.iter_fields(node)
#     104             if k not in ['body', 'orelse', 'finalbody']
#     105         })
#     106         for field in ['body', 'orelse', 'finalbody']:
#     107             if hasattr(node, field):
#
# Cell In[1], line 102, in clean_ast(node, bad_nodes)
#      99 def clean_ast(node, bad_nodes):
#     100     if isinstance(node, ast.AST):
#     101         new_node = type(node)(**{
# --> 102             k: clean_ast(v, bad_nodes)
#     103             for k, v in ast.iter_fields(node)
#     104             if k not in ['body', 'orelse', 'finalbody']
#     105         })
#     106         for field in ['body', 'orelse', 'finalbody']:
#     107             if hasattr(node, field):
#
# Cell In[1], line 116, in clean_ast(node, bad_nodes)
#     114     return new_node
#     115 elif isinstance(node, list):
# --> 116     return [clean_ast(child, bad_nodes) for child in node
#     117             if child not in bad_nodes]
#     118 else:
#     119     return node
#
# Cell In[1], line 109, in clean_ast(node, bad_nodes)
#     107 if hasattr(node, field):
#     108     new_body = []
# --> 109     for child in getattr(node, field):
#     110         cleaned = clean_ast(child, bad_nodes)
#     111         if cleaned not in bad_nodes and cleaned is not None:
#
# TypeError: 'Constant' object is not iterable

# %%
import ast as std_ast
import os
from pathlib import Path
from collections import defaultdict

class FunctionCallExtractor(std_ast.NodeVisitor):
    def __init__(self, project_modules):
        self.project_modules = project_modules
        self.call_graph = defaultdict(list)
        self.current_function = None
        
    def visit_FunctionDef(self, node):
        self.current_function = node.name
        self.call_graph[self.current_function] = []
        self.generic_visit(node)
        self.current_function = None
        
    def visit_Call(self, node):
        if self.current_function:
            call_name = self._get_call_name(node.func)
            if call_name:
                self.call_graph[self.current_function].append(call_name)
                
    def _get_call_name(self, node):
        if isinstance(node, std_ast.Name):
            return node.id
        elif isinstance(node, std_ast.Attribute):
            return f"{self._get_call_name(node.value)}.{node.attr}"
        return None

def get_project_modules(root_dir):
    modules = set()
    for path in Path(root_dir).rglob('*.py'):
        rel_path = path.relative_to(root_dir)
        module_parts = list(rel_path.parts)
        if module_parts[-1] == '__init__.py':
            module_parts.pop()
            modules.add('.'.join(module_parts))
        elif path.suffix == '.py':
            modules.add('.'.join(module_parts[:-1] + [path.stem]))
    return modules

def build_call_graph(root_dir):
    project_modules = get_project_modules(root_dir)
    call_graph = {}
    
    for py_file in Path(root_dir).rglob('*.py'):
        with open(py_file, 'r', encoding='utf-8') as f:
            code = f.read()
            
        try:
            tree = std_ast.parse(code)
            extractor = FunctionCallExtractor(project_modules)
            extractor.visit(tree)
            call_graph.update(extractor.call_graph)
        except Exception as e:
            print(f"Error parsing {py_file}: {e}")
            
    return call_graph

# Usage
project_root = '/nas/longleaf/home/zhw/personal/code_mapper/repos/b27d2ab10f64'
call_graph = build_call_graph(project_root)

# Print the simplified call graph
for func, calls in call_graph.items():
    print(f"Function: {func}")
    print(f"  Calls: {', '.join(calls)}")
    print()
# Out:
# Function: __init__
#   Calls: None.__init__, tv.resnet18, tv.resnet34, tv.resnet50, tv.resnet101, tv.resnet152
#
# Function: __repr__
#   Calls:
#
# Function: tr2q
#   Calls: sqrt, matrix, linalg.norm, matrix, sqrt
#
# Function: __add__
#   Calls: isinstance, quaternion
#
# Function: __sub__
#   Calls: isinstance, quaternion
#
# Function: __mul__
#   Calls: quaternion, isinstance, cross, type, quaternion, self.inv
#
# Function: __rmul__
#   Calls: quaternion
#
# Function: __imul__
#   Calls: isinstance, cross, isscalar
#
# Function: __pow__
#   Calls: isinstance, quaternion, quaternion, range, qr.inv
#
# Function: double
#   Calls: concatenate
#
# Function: unit_Q
#   Calls: quaternion, linalg.norm, sqrt
#
# Function: interpolate
#   Calls: Q1.double, Q2.double, acos, isscalar, Exception, quaternion, np.copy, quaternion, quaternion, q.append
#
# Function: MPIBokehRenderer_final
#   Calls: torch.sigmoid, torch.cat, mpi_image.reshape, alpha_new.reshape, torch.sum, None.squeeze, torch.cumprod, torch.sum
#
# Function: MPIBokehRenderer_blending_final
#   Calls: torch.sigmoid, torch.cat, torch.sigmoid, torch.cat, mpi_image_dy.reshape, alpha_dy.reshape, torch.sum, None.squeeze, mpi_image_rig.reshape, alpha_rig.reshape, torch.sum, None.squeeze, torch.cumprod, torch.sum
#
# Function: im2tensor
#   Calls: torch.Tensor
#
# Function: config_parser
#   Calls: configargparse.ArgumentParser, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument, parser.add_argument
#
# Function: calculate_psnr
#   Calls: img1.astype, img2.astype, mask.astype, np.sum, np.sum, math.log10
#
# Function: calculate_ssim
#   Calls: ValueError, structural_similarity, np.sum, np.sum
#
# Function: evaluation
#   Calls: config_parser, parser.parse_args, os.path.join, os.path.join, os.path.join, open, sorted, getattr, file.write, torch.no_grad, models.PerceptualLoss, time.time, os.listdir, os.path.join, img_i.replace, os.path.join, cv2.imread, np.float32, cv2.imread, cv2.resize, np.float32, compare_psnr, compare_ssim, None.cuda, im2tensor, im2tensor, None.cuda, model.forward, lpips.item, print, args.datadir.replace, os.path.join, np.float32, cv2.resize, torch.Tensor, calculate_ssim, calculate_psnr, None.item, open, file.write, file.write, file.write, print, print, print, print, print, print
#
# Function: _minify
#   Calls: os.path.join, os.path.exists, os.path.join, os.path.exists, os.path.join, os.path.join, sorted, any, os.getcwd, isinstance, None.format, None.format, None.format, None.format, os.path.join, os.path.exists, print, os.makedirs, check_output, None.split, None.join, print, os.chdir, check_output, os.chdir, check_output, print, print
#
# Function: _load_data
#   Calls: print, np.load, None.transpose, None.transpose, os.path.join, sorted, f.endswith, f.endswith, f.endswith, imageio.imread, None.format, _minify, float, int, None.format, float, int, None.format, os.path.join, os.path.exists, print, os.path.join, sorted, f.endswith, f.endswith, f.endswith, len, print, imageio.imread, None.reshape
#
# Function: imread
#   Calls: f.endswith, imageio.imread, imageio.imread
#
# Function: normalize
#   Calls: np.linalg.norm
#
# Function: viewmatrix
#   Calls: normalize, normalize, normalize, np.stack
#
# Function: poses_avg
#   Calls: None.mean, normalize, None.sum, np.concatenate
#
# Function: render_path_spiral
#   Calls: np.array, np.linspace, np.dot, normalize, render_poses.append
#
# Function: recenter_poses
#   Calls: np.reshape, poses_avg, np.concatenate, np.tile, np.concatenate, np.linalg.inv
#
# Function: read_MiDaS_disp
#   Calls: np.load
#
# Function: load_llff_data
#   Calls: _load_data, print, np.concatenate, None.astype, None.astype, None.astype, None.astype, None.astype, None.astype, np.percentile, recenter_poses, normalize, bds.min, bds.max, np.percentile, render_wander_path, None.astype, images.astype, poses.astype, disp.astype, masks.astype, bg_masks.astype
#
# Function: create_bt_poses
#   Calls: print, np.arcsin, float, range, np.sin, np.cos, np.concatenate, np.linalg.inv, output_poses.append
#
# Function: render_wander_path
#   Calls: range, np.sin, np.cos, np.cos, np.concatenate, np.linalg.inv, np.concatenate, np.dot, output_poses.append
#
# Function: mat2euler
#   Calls: np.asarray, np.finfo, math.sqrt, math.atan2, math.atan2, math.atan2, math.atan2, math.atan2
#
# Function: quat2euler
#   Calls: mat2euler
#
# Function: linear_translation
#   Calls:
#
# Function: qvec2rotmat
#   Calls: np.array
#
# Function: rotmat2qvec
#   Calls: np.array, np.linalg.eigh, np.argmax
#
# Function: linear_pose_interp
#   Calls: rotmat2qvec, rotmat2qvec, quaternion, quaternion, None.tolist, interpolate, q.v.tolist, qvec2rotmat, np.array
#
# Function: splat_rgb_img
#   Calls: torch.cat, None.cuda, NDC2Euclidean, NDC2Euclidean, se3_transform_points, perspective_projection, torch.meshgrid, xx.t, yy.t, torch.stack, None.cuda, softsplat.FunctionSoftsplat, se3_transform_points, perspective_projection, None.cuda, torch.cat, None.cuda, softsplat.FunctionSoftsplat
#
# Function: render_slowmo_bt
#   Calls: time.time, os.path.join, os.makedirs, enumerate, int, np.floor, print, time.time, linear_pose_interp, np.concatenate, np.concatenate, np.dot, None.to, None.transpose, torch.matmul, np.floor, float, np.floor, float, print, render_sm, render_sm, torch.ones, torch.zeros, range, splat_rgb_img, splat_rgb_img, os.path.join, to8b, os.path.join, imageio.imwrite
#
# Function: render_lockcam_slowmo
#   Calls: time.time, enumerate, np.floor, None.transpose, torch.matmul, np.floor, float, np.floor, float, print, time.time, render_sm, render_sm, torch.ones, torch.zeros, range, splat_rgb_img, splat_rgb_img, os.path.join, to8b, imageio.imwrite
#
# Function: render_sm
#   Calls: get_rays, get_rays, torch.norm, None.float, ndc_rays, None.float, None.float, torch.ones_like, torch.ones_like, torch.cat, torch.cat, batchify_rays_sm, list, list, torch.reshape
#
# Function: batchify_rays_sm
#   Calls: range, render_rays_sm, None.append, torch.cat
#
# Function: raw2rgba_blend_slowmo
#   Calls: torch.exp, torch.cat, torch.norm, torch.sigmoid, torch.randn, raw2alpha
#
# Function: render_rays_sm
#   Calls: torch.reshape, torch.linspace, z_vals.expand, torch.cat, torch.cat, torch.rand, torch.ones_like, torch.cat, get_rigid_outputs, network_query_fn, raw2rgba_blend_slowmo, raw2rgba_blend_slowmo
#
# Function: batchify
#   Calls:
#
# Function: ret
#   Calls: torch.cat
#
# Function: run_network
#   Calls: torch.reshape, embed_fn, None.expand, torch.reshape, embeddirs_fn, torch.cat, torch.reshape
#
# Function: batchify_rays
#   Calls: range, render_rays, None.append, torch.cat
#
# Function: batchify_rays_mpi_dsk
#   Calls: range, render_rays_mpi_dsk, None.append, torch.cat
#
# Function: render
#   Calls: get_rays, get_rays, torch.norm, None.float, ndc_rays, None.float, None.float, torch.ones_like, torch.ones_like, torch.cat, torch.cat, batchify_rays, list, list, torch.reshape
#
# Function: render_mpi_dsk
#   Calls: get_rays, get_rays, torch.norm, None.float, ndc_rays, None.float, None.float, torch.ones_like, torch.ones_like, torch.cat, torch.cat, batchify_rays_mpi_dsk, list, list, torch.reshape
#
# Function: render_bullet_time_new
#   Calls: time.time, range, print, time.time, render, None.numpy, rgbs.append
#
# Function: render_bullet_time
#   Calls: time.time, os.path.join, os.makedirs, range, print, time.time, render, torch.clamp, None.numpy, to8b, to8b, os.path.join, imageio.imwrite, rgbs.append, imageio.mimwrite
#
# Function: create_nerf
#   Calls: get_embedder, get_embedder, None.to, list, torch.nn.DataParallel, torch.nn.DataParallel, list, list, get_embedder, None.to, torch.nn.DataParallel, list, run_network, run_network, torch.optim.Adam, os.path.join, sorted, len, print, torch.load, optimizer.load_state_dict, model.load_state_dict, kernelnet.load_state_dict, print, model_rigid.load_state_dict, model_fine.load_state_dict, print
#
# Function: raw2outputs_blending
#   Calls: torch.cat, torch.norm, torch.sigmoid, torch.sigmoid, torch.randn, act_fn, act_fn, torch.exp, torch.exp, torch.cumprod, torch.sum, torch.sum, torch.max, torch.exp, torch.cumprod, torch.sum, torch.sum
#
# Function: raw2outputs_blending_mpi
#   Calls: torch.cat, torch.norm, torch.sigmoid, torch.sigmoid, torch.randn, act_fn, act_fn, torch.exp, torch.exp, torch.cumprod, torch.sum, MPIBokehRenderer_blending_final, torch.sum, torch.exp, torch.cumprod, torch.sum, torch.sum, MPIBokehRenderer_final
#
# Function: raw2outputs_warp
#   Calls: torch.cat, torch.norm, torch.sigmoid, torch.randn, act_fn, torch.exp, torch.cumprod, torch.sum, torch.sum, MPIBokehRenderer_final
#
# Function: raw2outputs
#   Calls: torch.exp, torch.cat, torch.norm, torch.sigmoid, torch.randn, raw2alpha, torch.cumprod, torch.sum, torch.sum, torch.max
#
# Function: raw2outputs_mpi
#   Calls: torch.exp, torch.cat, torch.norm, torch.sigmoid, torch.randn, raw2alpha, torch.cumprod, torch.sum, torch.sum, torch.max, MPIBokehRenderer_final
#
# Function: get_rigid_outputs
#   Calls: network_query_fn, raw2outputs
#
# Function: get_rigid_outputs_mpi
#   Calls: network_query_fn, raw2outputs_mpi
#
# Function: compute_2d_prob
#   Calls: torch.sum
#
# Function: render_rays
#   Calls: torch.reshape, torch.linspace, z_vals.expand, torch.cat, torch.cat, torch.rand, torch.ones_like, torch.cat, get_rigid_outputs, network_query_fn, raw2outputs_blending, None.detach, torch.ones_like, torch.cat, torch.ones_like, torch.cat, network_query_fn, raw2outputs_warp, network_query_fn, raw2outputs_warp, compute_2d_prob, compute_2d_prob, torch.ones_like, torch.cat, network_query_fn, raw2outputs_warp, torch.ones_like, torch.cat, network_query_fn, raw2outputs_warp, None.any, None.any, print
#
# Function: render_rays_mpi_dsk
#   Calls: torch.reshape, torch.linspace, z_vals.expand, torch.cat, torch.cat, torch.rand, torch.ones_like, torch.cat, get_rigid_outputs_mpi, network_query_fn, raw2outputs_blending_mpi, None.detach, torch.ones_like, torch.cat, torch.ones_like, torch.cat, network_query_fn, raw2outputs_warp, network_query_fn, raw2outputs_warp, compute_2d_prob, compute_2d_prob, torch.ones_like, torch.cat, network_query_fn, raw2outputs_warp, torch.ones_like, torch.cat, network_query_fn, raw2outputs_warp, None.any, None.any, print
#
# Function: init_linear_weights
#   Calls: isinstance, nn.init.xavier_normal_, nn.init.xavier_normal_, nn.init.constant_, isinstance, nn.init.xavier_normal_, nn.init.constant_
#
# Function: forward
#   Calls: self.conv1, self.bn1, self.relu, self.maxpool, self.layer1, self.layer2, self.layer3, self.layer4, namedtuple, outputs
#
# Function: train
#   Calls: config_parser, parser.parse_args, load_llff_data, print, print, np.arange, np.array, print, np.percentile, np.percentile, print, print, sys.exit, int, int, np.array, os.makedirs, os.path.join, open, sorted, getattr, file.write, os.path.join, open, file.write, DSKnet, create_nerf, render_kwargs_train.update, render_kwargs_test.update, print, None.to, print, float, float, os.path.join, os.makedirs, torch.no_grad, render_bullet_time, print, float, None.to, print, os.path.join, os.makedirs, torch.no_grad, render_lockcam_slowmo, print, create_bt_poses, torch.no_grad, os.path.join, os.makedirs, torch.Tensor, print, render_slowmo_bt, torch.Tensor, torch.Tensor, None.to, float, None.to, os.path.join, os.makedirs, torch.no_grad, render, None.numpy, os.path.join, imageio.imwrite, torch.Tensor, torch.Tensor, None.to, None.to, print, print, print, print, None.cuda, SummaryWriter, float, max, min, range, time.time, print, print, np.random.choice, torch.cuda.empty_cache, None.cuda, None.cuda, None.cuda, None.cuda, read_optical_flow_NVDS, np.zeros_like, np.zeros_like, read_optical_flow_NVDS, np.zeros_like, np.zeros_like, read_optical_flow_NVDS, read_optical_flow_NVDS, None.cuda, None.cuda, None.cuda, None.cuda, get_rays, torch.stack, torch.reshape, print, print, np.random.choice, np.random.choice, None.long, None.long, torch.cat, torch.stack, None.unsqueeze, None.unsqueeze, np.random.choice, None.long, np.meshgrid, np.tile, np.tile, np.reshape, np.reshape, None.cuda, None.cuda, torch.stack, None.unsqueeze, None.unsqueeze, print, render, kernelnet, render_mpi_dsk, render, min, max, compute_optical_flow, optimizer.zero_grad, torch.mean, torch.mean, img2mse, compute_mse, compute_mse, print, None.detach, compute_mse, compute_mse, compute_mse, img2mse, compute_mae, compute_mae, torch.sum, torch.sum, torch.mean, torch.mean, compute_depth_loss, print, print, compute_mae, print, compute_mae, compute_mae, compute_mae, compute_sf_sm_loss, compute_sf_sm_loss, compute_sf_lke_loss, compute_sf_lke_loss, torch.mean, compute_sf_lke_loss, compute_sf_lke_loss, compute_mse, print, print, print, loss.backward, optimizer.step, time.time, print, os.path.join, torch.save, torch.save, print, writer.add_scalar, writer.add_scalar, writer.add_scalar, writer.add_scalar, writer.add_scalar, writer.add_scalar, writer.add_scalar, writer.add_scalar, torch.min, torch.min, read_optical_flow_NVDS, np.zeros_like, np.zeros_like, read_optical_flow_NVDS, np.zeros_like, np.zeros_like, read_optical_flow_NVDS, read_optical_flow_NVDS, torch.Tensor, writer.add_image, torch.Tensor, writer.add_image, torch.no_grad, render, writer.add_image, writer.add_image, writer.add_image, writer.add_image, writer.add_image, writer.add_image, writer.add_image, writer.add_image, writer.add_image, writer.add_image, print, torch.min, os.path.join, os.makedirs, torch.no_grad, render, None.numpy, os.path.join, imageio.imwrite, print
#
# Function: create_embedding_fn
#   Calls: embed_fns.append, torch.linspace, torch.linspace, embed_fns.append
#
# Function: embed
#   Calls: torch.cat
#
# Function: get_embedder
#   Calls: nn.Identity, Embedder, eo.embed
#
# Function: get_rays
#   Calls: torch.meshgrid, i.t, j.t, torch.stack, torch.sum, None.expand
#
# Function: ndc_rays
#   Calls: torch.stack, torch.stack
#
# Function: compute_depth_loss
#   Calls: torch.median, torch.mean, torch.median, torch.mean, torch.mean
#
# Function: compute_mse
#   Calls: torch.squeeze, mask.repeat, mask.repeat, torch.sum, torch.sum
#
# Function: compute_mae
#   Calls: torch.squeeze, mask.repeat, mask.repeat, torch.sum, torch.sum
#
# Function: normalize_depth
#   Calls: torch.clamp
#
# Function: percentile
#   Calls: round, None.values.item
#
# Function: make_color_wheel
#   Calls: np.zeros, np.transpose, np.transpose, np.transpose, np.transpose, np.transpose, np.transpose
#
# Function: compute_color
#   Calls: np.zeros, np.isnan, np.isnan, make_color_wheel, np.size, np.sqrt, np.arctan2, None.astype, range, np.logical_not, np.uint8
#
# Function: flow_to_image
#   Calls: abs, abs, max, min, max, min, np.sqrt, max, print, np.finfo, np.finfo, compute_color, np.repeat, np.uint8
#
# Function: perspective_projection
#   Calls: torch.cat
#
# Function: se3_transform_points
#   Calls: torch.squeeze
#
# Function: NDC2Euclidean
#   Calls: torch.cat
#
# Function: projection_from_ndc
#   Calls: None.transpose, torch.matmul, torch.sum, NDC2Euclidean, se3_transform_points, se3_transform_points, perspective_projection
#
# Function: compute_optical_flow
#   Calls: projection_from_ndc, projection_from_ndc
#
# Function: read_optical_flow_NVDS
#   Calls: os.path.join, os.path.join, str, np.load, np.float32, os.path.join, np.load, np.float32
#
# Function: read_optical_flow
#   Calls: os.path.join, os.path.join, str, np.load, np.float32, os.path.join, np.load, np.float32
#
# Function: warp_flow
#   Calls: flow.copy, np.arange, np.arange, cv2.remap
#
# Function: compute_sf_sm_loss
#   Calls: int, int, NDC2Euclidean, NDC2Euclidean, torch.mean
#
# Function: compute_sf_lke_loss
#   Calls: int, int, int, NDC2Euclidean, NDC2Euclidean, NDC2Euclidean, torch.mean
#
# Function: sample_pdf
#   Calls: torch.sum, torch.cumsum, torch.cat, torch.linspace, u.expand, torch.rand, np.random.seed, list, np.linspace, np.broadcast_to, np.random.rand, torch.Tensor, u.contiguous, torch.searchsorted, torch.max, torch.min, torch.stack, torch.gather, torch.gather, torch.where
#
# Function: cupy_kernel
#   Calls: globals, re.search, int, objMatch.group, None.size, strKernel.replace, re.search, int, None.split, None.stride, None.strip, str, range, strKernel.replace, re.search, int, None.split, None.stride, None.strip, str, range, strKernel.replace
#
# Function: cupy_launch
#   Calls: None.get_function, cupy.memoize
#
# Function: backward
#   Calls: gradOutput.is_contiguous, input.new_zeros, input.new_zeros, gradInput.nelement, gradFlow.nelement, NotImplementedError
#
# Function: FunctionSoftsplat
#   Calls: torch.cat, torch.cat, torch.cat, _FunctionSoftsplat.apply
#
# Function: normalize_tensor
#   Calls: torch.sqrt
#
# Function: l2
#   Calls: np.mean
#
# Function: psnr
#   Calls: np.log10
#
# Function: dssim
#   Calls: compare_ssim
#
# Function: rgb2lab
#   Calls: color.rgb2lab
#
# Function: tensor2np
#   Calls: None.transpose
#
# Function: np2tensor
#   Calls: torch.Tensor
#
# Function: tensor2tensorlab
#   Calls: tensor2im, color.rgb2lab, np2tensor
#
# Function: tensorlab2tensor
#   Calls: warnings.filterwarnings, tensor2np, np.clip, color.rgb2lab, np.isclose, np2tensor, im2tensor, im2tensor
#
# Function: tensor2im
#   Calls: None.numpy, np.transpose, image_numpy.astype
#
# Function: tensor2vec
#   Calls: None.numpy
#
# Function: voc_ap
#   Calls: np.arange, np.sum, np.max, np.concatenate, np.concatenate, range, np.maximum, np.where, np.sum
#
# Function: name
#   Calls:
#
# Function: initialize
#   Calls: BaseModel.initialize, networks.PNetLin, os.path.abspath, print, self.net.load_state_dict, networks.PNetLin, networks.L2, networks.DSSIM, ValueError, list, networks.BCERankingLoss, list, torch.optim.Adam, self.net.eval, self.net.to, torch.nn.DataParallel, self.rankLoss.to, print, networks.print_network, print
#
# Function: get_image_paths
#   Calls:
#
# Function: optimize_parameters
#   Calls: self.forward_train, self.optimizer_net.zero_grad, self.backward_train, self.optimizer_net.step, self.clamp_weights
#
# Function: get_current_visuals
#   Calls: self.var_ref.data.size, util.tensor2im, util.tensor2im, util.tensor2im, zoom, zoom, zoom, OrderedDict
#
# Function: get_current_errors
#   Calls: OrderedDict, retDict.keys, np.mean
#
# Function: save
#   Calls: self.save_network, self.save_network, self.save_network
#
# Function: save_network
#   Calls: os.path.join, torch.save
#
# Function: load_network
#   Calls: os.path.join, print, network.load_state_dict
#
# Function: update_learning_rate
#   Calls: print
#
# Function: save_done
#   Calls: np.save, np.savetxt
#
# Function: clamp_weights
#   Calls: self.net.modules, hasattr, torch.clamp
#
# Function: set_input
#   Calls: self.input_ref.to, self.input_p0.to, self.input_p1.to, self.input_judge.to, Variable, Variable, Variable
#
# Function: forward_train
#   Calls: self.forward, self.forward, self.compute_accuracy, None.view, self.rankLoss.forward
#
# Function: backward_train
#   Calls: None.backward
#
# Function: compute_accuracy
#   Calls: None.flatten, None.flatten
#
# Function: score_2afc_dataset
#   Calls: tqdm, None.tolist, None.tolist, None.tolist, np.array, np.array, np.array, np.mean, dict
#
# Function: score_jnd_dataset
#   Calls: tqdm, None.tolist, None.tolist, np.array, np.array, np.argsort, np.cumsum, np.cumsum, np.sum, util.voc_ap, dict
#
# Function: spatial_average
#   Calls: in_tens.mean, torch.nn.functional.interpolate, torch.sum, torch.sum
#
# Function: upsample
#   Calls:
#
# Function: print_network
#   Calls: net.parameters, param.numel, print, print

# %%
import ast as std_ast
import json
import os
from pathlib import Path
from collections import defaultdict

class CallTreeBuilder(std_ast.NodeVisitor):
    def __init__(self, current_module, file_path):
        self.current_module = current_module
        self.file_path = file_path
        self.call_graph = defaultdict(list)
        self.current_context = []  # Stack for tracking context
        self.source_lines = None
        self.ast_map = {}  # Map of function nodes by qualified name
        
        # Read the source file to extract line information
        with open(file_path, 'r', encoding='utf-8') as f:
            self.source_lines = f.readlines()
            
    def get_source_line(self, node):
        """Get the actual source line for a node"""
        if not hasattr(node, 'lineno'):
            return None
        
        if self.source_lines:
            # AST line numbers are 1-based
            return self.source_lines[node.lineno - 1].strip()
        return None
        
    def visit_Module(self, node):
        # Add main block as "__main__"
        main_name = f"{self.current_module}.__main__"
        self.call_graph[main_name] = []
        self.current_context.append(main_name)
        self.generic_visit(node)
        self.current_context.pop()
        
    def visit_FunctionDef(self, node):
        qual_name = f"{self.current_module}.{node.name}"
        self.current_context.append(qual_name)
        self.call_graph[qual_name] = []
        
        # Store AST node reference for function definitions
        self.ast_map[qual_name] = {
            'node': node,
            'ast_id': id(node),
            'line_range': (node.lineno, self._get_last_line(node))
        }
        
        self.generic_visit(node)
        self.current_context.pop()
        
    def _get_last_line(self, node):
        """Get the last line number of a node"""
        # Find the maximum line number in the node
        if hasattr(node, 'end_lineno') and node.end_lineno is not None:
            return node.end_lineno
            
        max_line = getattr(node, 'lineno', 0)
        for field, value in std_ast.iter_fields(node):
            if isinstance(value, list):
                for item in value:
                    if isinstance(item, std_ast.AST):
                        item_last_line = self._get_last_line(item)
                        max_line = max(max_line, item_last_line)
            elif isinstance(value, std_ast.AST):
                value_last_line = self._get_last_line(value)
                max_line = max(max_line, value_last_line)
        return max_line
        
    def visit_If(self, node):
        # Handle __name__ == "__main__" blocks
        if self._is_main_check(node.test):
            main_name = f"{self.current_module}.__main__"
            current_context_len = len(self.current_context)
            
            # Only append to context if we're not already in __main__ context
            if not self.current_context or self.current_context[-1] != main_name:
                self.current_context.append(main_name)
                
            # Visit the body of the if statement to find calls
            for subnode in node.body:
                self.visit(subnode)
                
            # Pop if we added to the context
            if len(self.current_context) > current_context_len:
                self.current_context.pop()
        else:
            self.generic_visit(node)
            
    def visit_Call(self, node):
        if self.current_context:
            caller = self.current_context[-1]
            callee, is_internal = self._get_call_name(node.func)
            
            if callee and is_internal:
                # Only add internal function calls
                self.call_graph[caller].append({
                    'name': callee,
                    'ast_id': id(node),
                    'lineno': node.lineno,
                    'source': self.get_source_line(node)
                })
                
    def _is_main_check(self, test_node):
        return (
            isinstance(test_node, std_ast.Compare) and
            isinstance(test_node.left, std_ast.Name) and
            test_node.left.id == '__name__' and
            any(
                isinstance(op, std_ast.Eq) and
                isinstance(comparator, (std_ast.Constant, std_ast.Str)) and
                (
                    (hasattr(comparator, 'value') and comparator.value == '__main__') or
                    (hasattr(comparator, 's') and comparator.s == '__main__')
                )
                for op, comparator in zip(test_node.ops, test_node.comparators)
            )
        )

    def _get_call_name(self, node):
        """Get the call name and determine if it's an internal function call"""
        if isinstance(node, std_ast.Name):
            # Simple function call like 'foo()'
            # This is likely an internal function in the same module
            full_name = f"{self.current_module}.{node.id}"
            return full_name, True
            
        elif isinstance(node, std_ast.Attribute):
            # Attribute access like 'module.function()'
            base_obj = node.value
            
            # Handle direct project imports (e.g., from myproject import module)
            if isinstance(base_obj, std_ast.Name):
                # Simplified approach: assume one-part names are internal
                # packages have dots in them
                if '.' not in base_obj.id:
                    # Potentially an internal module, construct a qualified name
                    return f"{base_obj.id}.{node.attr}", True
            
            # Not an internal call
            return None, False
            
        return None, False

def extract_code_segments(file_path, function_name, call_positions):
    """Extract code segments between function calls"""
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    
    # Get function definition bounds
    with open(file_path, 'r', encoding='utf-8') as f:
        tree = std_ast.parse(f.read())
    
    function_node = None
    for node in std_ast.walk(tree):
        if isinstance(node, std_ast.FunctionDef) and node.name == function_name:
            function_node = node
            break
    
    if not function_node:
        return []
    
    # Get function body line range
    start_line = function_node.lineno
    end_line = 0
    for node in std_ast.walk(function_node):
        if hasattr(node, 'lineno'):
            end_line = max(end_line, getattr(node, 'end_lineno', node.lineno))
    
    # Sort call positions by line number
    call_positions.sort(key=lambda x: x['lineno'])
    
    # Extract code segments between calls
    segments = []
    last_pos = start_line
    
    for call in call_positions:
        if call['lineno'] > last_pos:
            # Extract code segment from last_pos to call_pos
            segment = ''.join(lines[last_pos:call['lineno']-1])
            if segment.strip():
                segments.append({
                    'type': 'code',
                    'content': segment.strip()
                })
        
        # Add the function call
        segments.append({
            'type': 'call',
            'content': call['source'],
            'callee': call['name'],
            'ast_id': call['ast_id']
        })
        
        last_pos = call['lineno']
    
    # Add final segment after last call
    if last_pos < end_line:
        segment = ''.join(lines[last_pos:end_line])
        if segment.strip():
            segments.append({
                'type': 'code',
                'content': segment.strip()
            })
    
    return segments

def build_call_tree(project_root, entry_file, entry_function, max_depth):
    # Convert paths to absolute
    project_root = os.path.abspath(project_root)
    entry_file = os.path.abspath(entry_file)
    
    # Build call graph and extract function code segments
    call_graph = defaultdict(list)
    function_segments = {}
    
    # Map of module names to file paths
    module_files = {}
    
    for py_file in Path(project_root).rglob('*.py'):
        # Get module name from file path
        relative_path = py_file.relative_to(project_root)
        if py_file.name == '__init__.py':
            module_name = '.'.join(relative_path.parent.parts)
        else:
            module_name = '.'.join(relative_path.with_suffix('').parts)
        
        module_files[module_name] = py_file
            
        with open(py_file, 'r', encoding='utf-8') as f:
            try:
                tree = std_ast.parse(f.read())
                
                builder = CallTreeBuilder(module_name, py_file)
                builder.visit(tree)
                
                # Update call graph with only internal calls
                for caller, calls in builder.call_graph.items():
                    if calls:  # Only add if there are calls
                        call_graph[caller] = calls
                
                # Create a map of function nodes and their code segments
                for func_name, calls in builder.call_graph.items():
                    # Skip __main__ blocks for now
                    if not func_name.endswith('__main__'):
                        # Extract the function name without module
                        simple_name = func_name.split('.')[-1]
                        function_segments[func_name] = extract_code_segments(
                            py_file, simple_name, calls
                        )
                
            except Exception as e:
                print(f"Error parsing {py_file}: {e}")
    
    # Handle __main__ entry point
    entry_point = None
    if entry_function == "__main__":
        entry_path = Path(entry_file).relative_to(project_root).with_suffix('')
        entry_point = f"{'.'.join(entry_path.parts)}.__main__"
    else:
        # Extract module name from entry file
        entry_path = Path(entry_file).relative_to(project_root)
        if entry_path.name == '__init__.py':
            module_name = '.'.join(entry_path.parent.parts)
        else:
            module_name = '.'.join(entry_path.with_suffix('').parts)
        
        entry_point = f"{module_name}.{entry_function}"
    
    # Check if entry point exists in call graph
    if entry_point not in call_graph:
        print(f"Warning: Entry point {entry_point} not found in call graph.")
        print("Available entry points:")
        for key in call_graph.keys():
            print(f"  - {key}")
        return None
    
    # Build the call tree
    def _recurse(current_func, depth, visited):
        if depth > max_depth or current_func in visited:
            return None
        
        # Split the function name to get just the function part
        module_parts = current_func.split('.')
        func_name = module_parts[-1]
        
        node = {
            "name": func_name,  # Just the function name
            "original": current_func,  # Full qualified name
            "children": []
        }
        
        # Add code segments if available
        if current_func in function_segments:
            node["segments"] = function_segments[current_func]
        
        if depth < max_depth:
            visited.add(current_func)
            
            # Add child function calls
            for call in call_graph.get(current_func, []):
                callee_name = call['name']
                
                # Create child node for the function call
                child_node = {
                    "name": callee_name.split('.')[-1],  # Just the function name
                    "original": callee_name,  # Full qualified name
                    "ast_id": call['ast_id'],
                    "call_line": call['source'],
                    "children": []
                }
                
                # Recursively process this child if it's in our call graph
                child_result = _recurse(callee_name, depth + 1, visited.copy())
                if child_result:
                    # Merge attributes from recursive result
                    for key, value in child_result.items():
                        if key != "name" and key != "original":  # Keep our name and original
                            child_node[key] = value
                
                node["children"].append(child_node)
                        
        return node
    
    # Start from entry point
    result = _recurse(entry_point, 1, set())
    return result

# # Complete runnable example
# if __name__ == "__main__":
#     import sys
    
#     if len(sys.argv) < 3:
#         print("Usage: python script.py project_root entry_file [entry_function] [max_depth]")
#         sys.exit(1)
    
#     project_root = sys.argv[1]
#     entry_file = sys.argv[2]
#     entry_function = sys.argv[3] if len(sys.argv) > 3 else "__main__"
#     max_depth = int(sys.argv[4]) if len(sys.argv) > 4 else 4
    
#     call_tree = build_call_tree(
#         project_root=project_root,
#         entry_file=entry_file,
#         entry_function=entry_function,
#         max_depth=max_depth
#     )
    
#     print(json.dumps(call_tree, indent=2))

# %%
project_root = "/nas/longleaf/home/zhw/personal/code_mapper/repos/b27d2ab10f64/"  # Define your project root
entry_file = "/nas/longleaf/home/zhw/personal/code_mapper/repos/b27d2ab10f64/run_nerf.py"  # Full path to entry file
entry_function = "__main__"  # Function name in entry file
max_depth = 2

call_tree = build_call_tree(
    project_root=project_root,
    entry_file=entry_file,
    entry_function=entry_function,
    max_depth=max_depth
)

# Print JSON output
print(json.dumps(call_tree, indent=2))
# Out:
# /tmp/ipykernel_4173281/887644484.py:112: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   isinstance(comparator, (std_ast.Constant, std_ast.Str)) and
# {
#   "name": "__main__",
#   "original": "run_nerf.__main__",
#   "children": [
#     {
#       "name": "device",
#       "original": "torch.device",
#       "ast_id": 140013623043216,
#       "call_line": "device = torch.device(\"cuda\" if torch.cuda.is_available() else \"cpu\")",
#       "children": []
#     },
#     {
#       "name": "set_default_tensor_type",
#       "original": "torch.set_default_tensor_type",
#       "ast_id": 140013624058768,
#       "call_line": "torch.set_default_tensor_type('torch.cuda.FloatTensor')",
#       "children": []
#     },
#     {
#       "name": "train",
#       "original": "run_nerf.train",
#       "ast_id": 140013624064208,
#       "call_line": "train()",
#       "children": [],
#       "segments": [
#         {
#           "type": "call",
#           "content": "parser = config_parser()",
#           "callee": "run_nerf.config_parser",
#           "ast_id": 140013626256272
#         },
#         {
#           "type": "call",
#           "content": "args = parser.parse_args()",
#           "callee": "parser.parse_args",
#           "ast_id": 140013626253904
#         },
#         {
#           "type": "code",
#           "content": "# Load data\n    if args.dataset_type == 'llff':\n        target_idx = args.target_idx\n        images, depths, masks, poses, bds, \\"
#         },
#         {
#           "type": "call",
#           "content": "render_poses, ref_c2w, motion_coords,bg_masks = load_llff_data(args.datadir,",
#           "callee": "run_nerf.load_llff_data",
#           "ast_id": 140013626250832
#         },
#         {
#           "type": "code",
#           "content": "args.start_frame, args.end_frame,\n                                                            args.factor,\n                                                            target_idx=target_idx,\n                                                            recenter=True, bd_factor=.9,\n                                                            spherify=args.spherify, \n                                                            final_height=args.final_height)\n\n        hwf = poses[0,:3,-1]\n        poses = poses[:,:3,:4]"
#         },
#         {
#           "type": "call",
#           "content": "print('Loaded llff', images.shape, render_poses.shape, hwf, args.datadir)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013628011920
#         },
#         {
#           "type": "code",
#           "content": "##modified by lxr\n        # i_test = []\n        i_val = [] #i_test\n        if args.llffhold > 0:"
#         },
#         {
#           "type": "call",
#           "content": "print('Auto LLFF holdout,', args.llffhold)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013625415824
#         },
#         {
#           "type": "code",
#           "content": "# i_test = np.arange(images.shape[0])[::args.llffhold]"
#         },
#         {
#           "type": "call",
#           "content": "i_test = np.arange(images.shape[0])[1::args.llffhold]",
#           "callee": "np.arange",
#           "ast_id": 140013625418640
#         },
#         {
#           "type": "call",
#           "content": "i_train = np.array([i for i in np.arange(int(images.shape[0])) if",
#           "callee": "np.array",
#           "ast_id": 140013625409744
#         },
#         {
#           "type": "code",
#           "content": "(i not in i_test and i not in i_val)])"
#         },
#         {
#           "type": "call",
#           "content": "print('DEFINING BOUNDS')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013625422544
#         },
#         {
#           "type": "code",
#           "content": "if args.no_ndc:"
#         },
#         {
#           "type": "call",
#           "content": "near = np.percentile(bds[:, 0], 5) * 0.8 #np.ndarray.min(bds) #* .9",
#           "callee": "np.percentile",
#           "ast_id": 140013625423888
#         },
#         {
#           "type": "call",
#           "content": "far = np.percentile(bds[:, 1], 95) * 1.1 #np.ndarray.max(bds) #* 1.",
#           "callee": "np.percentile",
#           "ast_id": 140013625410512
#         },
#         {
#           "type": "code",
#           "content": "else:\n            near = 0.\n            far = 1."
#         },
#         {
#           "type": "call",
#           "content": "print('NEAR FAR', near, far)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013625410640
#         },
#         {
#           "type": "code",
#           "content": "else:"
#         },
#         {
#           "type": "call",
#           "content": "print('ONLY SUPPORT LLFF!!!!!!!!')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013625418768
#         },
#         {
#           "type": "call",
#           "content": "sys.exit()",
#           "callee": "sys.exit",
#           "ast_id": 140013625417744
#         },
#         {
#           "type": "code",
#           "content": "# Cast intrinsics to right types\n    H, W, focal = hwf"
#         },
#         {
#           "type": "call",
#           "content": "H, W = int(H), int(W)",
#           "callee": "run_nerf.int",
#           "ast_id": 140013624478928
#         },
#         {
#           "type": "call",
#           "content": "H, W = int(H), int(W)",
#           "callee": "run_nerf.int",
#           "ast_id": 140013624486160
#         },
#         {
#           "type": "code",
#           "content": "hwf = [H, W, focal]\n    K=None\n    if K is None:"
#         },
#         {
#           "type": "call",
#           "content": "K = np.array([",
#           "callee": "np.array",
#           "ast_id": 140013624482640
#         },
#         {
#           "type": "code",
#           "content": "[focal, 0, 0.5 * W],\n            [0, focal, 0.5 * H],\n            [0, 0, 1]\n        ])\n\n    # Create log dir and copy the config file\n    basedir = args.basedir\n    \n    expname=args.expname"
#         },
#         {
#           "type": "call",
#           "content": "os.makedirs(os.path.join(basedir, expname), exist_ok=True)",
#           "callee": "os.makedirs",
#           "ast_id": 140013624475728
#         },
#         {
#           "type": "code",
#           "content": "f = os.path.join(basedir, expname, 'args.txt')"
#         },
#         {
#           "type": "call",
#           "content": "with open(f, 'w') as file:",
#           "callee": "run_nerf.open",
#           "ast_id": 140013624477264
#         },
#         {
#           "type": "call",
#           "content": "for arg in sorted(vars(args)):",
#           "callee": "run_nerf.sorted",
#           "ast_id": 140013624486736
#         },
#         {
#           "type": "call",
#           "content": "attr = getattr(args, arg)",
#           "callee": "run_nerf.getattr",
#           "ast_id": 140013624489168
#         },
#         {
#           "type": "call",
#           "content": "file.write('{} = {}\\n'.format(arg, attr))",
#           "callee": "file.write",
#           "ast_id": 140013624483984
#         },
#         {
#           "type": "code",
#           "content": "if args.config is not None:\n        f = os.path.join(basedir, expname, 'config.txt')"
#         },
#         {
#           "type": "call",
#           "content": "with open(f, 'w') as file:",
#           "callee": "run_nerf.open",
#           "ast_id": 140013624457744
#         },
#         {
#           "type": "call",
#           "content": "file.write(open(args.config, 'r').read())",
#           "callee": "file.write",
#           "ast_id": 140013624446992
#         },
#         {
#           "type": "code",
#           "content": "num_pt=args.num_pt\n    kernel_window=args.kernel_window"
#         },
#         {
#           "type": "call",
#           "content": "kernelnet = DSKnet(len(images), torch.tensor(poses[:, :3, :4]),",
#           "callee": "run_nerf.DSKnet",
#           "ast_id": 140013624452496
#         },
#         {
#           "type": "code",
#           "content": "num_pt=num_pt, kernel_hwindow=kernel_window,\n                           random_hwindow=0.15, in_embed=2,\n                           random_mode='input',\n                           img_embed=32,\n                           spatial_embed=2,\n                           depth_embed=0,\n                           num_hidden=4,\n                           num_wide=64,\n                           short_cut=True,\n                           optim_spatialvariant_trans=True)\n\n    # Create nerf model\n    args.N_image = images.shape[0]//2"
#         },
#         {
#           "type": "call",
#           "content": "render_kwargs_train, render_kwargs_test, start, grad_vars, optimizer,kernelnet = create_nerf(args,kernelnet)",
#           "callee": "run_nerf.create_nerf",
#           "ast_id": 140013624443024
#         },
#         {
#           "type": "code",
#           "content": "global_step = start\n\n    bds_dict = {\n        'near' : near,\n        'far' : far,\n    }"
#         },
#         {
#           "type": "call",
#           "content": "render_kwargs_train.update(bds_dict)",
#           "callee": "render_kwargs_train.update",
#           "ast_id": 140013622589904
#         },
#         {
#           "type": "call",
#           "content": "render_kwargs_test.update(bds_dict)",
#           "callee": "render_kwargs_test.update",
#           "ast_id": 140013622581072
#         },
#         {
#           "type": "code",
#           "content": "if args.render_bt:"
#         },
#         {
#           "type": "call",
#           "content": "print('RENDER VIEW INTERPOLATION')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013622577360
#         },
#         {
#           "type": "code",
#           "content": "render_poses = torch.Tensor(render_poses).to(device)"
#         },
#         {
#           "type": "call",
#           "content": "print('target_idx ', target_idx)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013622590928
#         },
#         {
#           "type": "call",
#           "content": "num_img = float(poses.shape[0])",
#           "callee": "run_nerf.float",
#           "ast_id": 140013622577680
#         },
#         {
#           "type": "call",
#           "content": "img_idx_embed = target_idx/float(num_img) * 2. - 1.0",
#           "callee": "run_nerf.float",
#           "ast_id": 140013622575440
#         },
#         {
#           "type": "code",
#           "content": "testsavedir = os.path.join(basedir, expname, \n                                'render-spiral-frame-%03d'%\\\n                                target_idx + '_{}_{:06d}'.format('test' if args.render_test else 'path', start))"
#         },
#         {
#           "type": "call",
#           "content": "os.makedirs(testsavedir, exist_ok=True)",
#           "callee": "os.makedirs",
#           "ast_id": 140013622581904
#         },
#         {
#           "type": "call",
#           "content": "with torch.no_grad():",
#           "callee": "torch.no_grad",
#           "ast_id": 140013622582928
#         },
#         {
#           "type": "call",
#           "content": "render_bullet_time(render_poses, img_idx_embed, num_img, hwf,",
#           "callee": "run_nerf.render_bullet_time",
#           "ast_id": 140013622583120
#         },
#         {
#           "type": "code",
#           "content": "args.chunk, render_kwargs_test, \n                               gt_imgs=images, savedir=testsavedir, \n                               render_factor=args.render_factor)\n\n        return\n\n    if args.render_lockcam_slowmo:"
#         },
#         {
#           "type": "call",
#           "content": "print('RENDER TIME INTERPOLATION')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013622589712
#         },
#         {
#           "type": "call",
#           "content": "num_img = float(poses.shape[0])",
#           "callee": "run_nerf.float",
#           "ast_id": 140013623064400
#         },
#         {
#           "type": "code",
#           "content": "ref_c2w = torch.Tensor(ref_c2w).to(device)"
#         },
#         {
#           "type": "call",
#           "content": "print('target_idx ', target_idx)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013623062608
#         },
#         {
#           "type": "code",
#           "content": "testsavedir = os.path.join(basedir, expname, 'render-lockcam-slowmo')"
#         },
#         {
#           "type": "call",
#           "content": "os.makedirs(testsavedir, exist_ok=True)",
#           "callee": "os.makedirs",
#           "ast_id": 140013623050704
#         },
#         {
#           "type": "call",
#           "content": "with torch.no_grad():",
#           "callee": "torch.no_grad",
#           "ast_id": 140013623060432
#         },
#         {
#           "type": "call",
#           "content": "render_lockcam_slowmo(ref_c2w, num_img, hwf,",
#           "callee": "run_nerf.render_lockcam_slowmo",
#           "ast_id": 140013623055760
#         },
#         {
#           "type": "code",
#           "content": "args.chunk, render_kwargs_test, \n                            gt_imgs=images, savedir=testsavedir, \n                            render_factor=args.render_factor,\n                            target_idx=target_idx)\n\n            return \n\n    if args.render_slowmo_bt:"
#         },
#         {
#           "type": "call",
#           "content": "print('RENDER SLOW MOTION')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013623057232
#         },
#         {
#           "type": "code",
#           "content": "curr_ts = 0\n        render_poses = poses #torch.Tensor(poses).to(device)"
#         },
#         {
#           "type": "call",
#           "content": "bt_poses = create_bt_poses(hwf)",
#           "callee": "run_nerf.create_bt_poses",
#           "ast_id": 140013623052944
#         },
#         {
#           "type": "code",
#           "content": "bt_poses = bt_poses * 10"
#         },
#         {
#           "type": "call",
#           "content": "with torch.no_grad():",
#           "callee": "torch.no_grad",
#           "ast_id": 140013623064784
#         },
#         {
#           "type": "code",
#           "content": "testsavedir = os.path.join(basedir, expname, \n                                    'render-slowmo_bt_{}_{:06d}'.format('test' if args.render_test else 'path', start))"
#         },
#         {
#           "type": "call",
#           "content": "os.makedirs(testsavedir, exist_ok=True)",
#           "callee": "os.makedirs",
#           "ast_id": 140013622422672
#         },
#         {
#           "type": "call",
#           "content": "images = torch.Tensor(images)#.to(device)",
#           "callee": "torch.Tensor",
#           "ast_id": 140013622423056
#         },
#         {
#           "type": "call",
#           "content": "print('render poses shape', render_poses.shape)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013622414736
#         },
#         {
#           "type": "call",
#           "content": "render_slowmo_bt(depths, render_poses, bt_poses,",
#           "callee": "run_nerf.render_slowmo_bt",
#           "ast_id": 140013622416656
#         },
#         {
#           "type": "code",
#           "content": "hwf, args.chunk, render_kwargs_test,\n                            gt_imgs=images, savedir=testsavedir, \n                            render_factor=args.render_factor, \n                            target_idx=10)\n            # print('Done rendering', i,testsavedir)\n\n        return\n\n    if args.render_test:"
#         },
#         {
#           "type": "call",
#           "content": "images = torch.Tensor(images)#.to(device)",
#           "callee": "torch.Tensor",
#           "ast_id": 140013622421200
#         },
#         {
#           "type": "call",
#           "content": "depths = torch.Tensor(depths)#.to(device)",
#           "callee": "torch.Tensor",
#           "ast_id": 140013622414224
#         },
#         {
#           "type": "code",
#           "content": "masks = torch.Tensor(bg_masks).to(device)"
#         },
#         {
#           "type": "call",
#           "content": "num_img = float(images.shape[0])",
#           "callee": "run_nerf.float",
#           "ast_id": 140013622413712
#         },
#         {
#           "type": "code",
#           "content": "poses = torch.Tensor(poses).to(device)\n        for img_i in i_test:\n                target = images[img_i]\n                pose = poses[img_i, :3,:4]\n\n                img_idx_embed = img_i/num_img * 2. - 1.0\n                testsavedir = os.path.join(basedir, expname, 'testset_{:06d}'.format(start))"
#         },
#         {
#           "type": "call",
#           "content": "os.makedirs(testsavedir, exist_ok=True)",
#           "callee": "os.makedirs",
#           "ast_id": 140013622315152
#         },
#         {
#           "type": "call",
#           "content": "with torch.no_grad():",
#           "callee": "torch.no_grad",
#           "ast_id": 140013622319184
#         },
#         {
#           "type": "code",
#           "content": "# if i<args.N_iters:"
#         },
#         {
#           "type": "call",
#           "content": "ret = render(img_idx_embed,",
#           "callee": "run_nerf.render",
#           "ast_id": 140013622327504
#         },
#         {
#           "type": "code",
#           "content": "0, False,\n                            num_img, H, W, focal, \n                            chunk=1024*16, \n                            c2w=pose,\n                            **render_kwargs_test)\n                rgb = ret['rgb_map_ref'].cpu().numpy()\n                save_img_path = os.path.join(testsavedir, \n                                    '%06d_right.png'%((img_i-1)//2))"
#         },
#         {
#           "type": "call",
#           "content": "imageio.imwrite(save_img_path,",
#           "callee": "imageio.imwrite",
#           "ast_id": 140013622324816
#         },
#         {
#           "type": "code",
#           "content": "to8b(rgb))\n        return\n\n    # Prepare raybatch tensor if batching random rays\n    N_rand = args.N_rand\n    # Move training data to GPU"
#         },
#         {
#           "type": "call",
#           "content": "images = torch.Tensor(images)#.to(device)",
#           "callee": "torch.Tensor",
#           "ast_id": 140013622321616
#         },
#         {
#           "type": "call",
#           "content": "depths = torch.Tensor(depths)#.to(device)",
#           "callee": "torch.Tensor",
#           "ast_id": 140013622326480
#         },
#         {
#           "type": "code",
#           "content": "masks = torch.Tensor(bg_masks).to(device)\n\n    poses = torch.Tensor(poses).to(device)\n\n    N_iters = args.N_iters+args.bokeh_iters+1"
#         },
#         {
#           "type": "call",
#           "content": "print('Begin')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013646926928
#         },
#         {
#           "type": "call",
#           "content": "print('TRAIN views are', i_train)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013646927376
#         },
#         {
#           "type": "call",
#           "content": "print('TEST views are', i_test)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013646924112
#         },
#         {
#           "type": "call",
#           "content": "print('VAL views are', i_val)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013646923152
#         },
#         {
#           "type": "code",
#           "content": "uv_grid = create_meshgrid(H, W, normalized_coordinates=False)[0].cuda() # (H, W, 2)\n\n    # Summary writers"
#         },
#         {
#           "type": "call",
#           "content": "writer = SummaryWriter(os.path.join(basedir, 'summaries', expname))",
#           "callee": "run_nerf.SummaryWriter",
#           "ast_id": 140013646922000
#         },
#         {
#           "type": "call",
#           "content": "num_img = float(images.shape[0])",
#           "callee": "run_nerf.float",
#           "ast_id": 140013646934416
#         },
#         {
#           "type": "call",
#           "content": "decay_iteration = max(args.decay_iteration,",
#           "callee": "run_nerf.max",
#           "ast_id": 140013646935184
#         },
#         {
#           "type": "code",
#           "content": "args.end_frame - args.start_frame)"
#         },
#         {
#           "type": "call",
#           "content": "decay_iteration = min(decay_iteration, 250)",
#           "callee": "run_nerf.min",
#           "ast_id": 140013646934224
#         },
#         {
#           "type": "code",
#           "content": "chain_bwd = 0"
#         },
#         {
#           "type": "call",
#           "content": "for i in range(start, N_iters):",
#           "callee": "run_nerf.range",
#           "ast_id": 140013625894416
#         },
#         {
#           "type": "code",
#           "content": "chain_bwd = 1 - chain_bwd"
#         },
#         {
#           "type": "call",
#           "content": "time0 = time.time()",
#           "callee": "time.time",
#           "ast_id": 140013625898512
#         },
#         {
#           "type": "call",
#           "content": "print('expname ', expname, ' chain_bwd ', chain_bwd,",
#           "callee": "run_nerf.print",
#           "ast_id": 140013625894288
#         },
#         {
#           "type": "code",
#           "content": "' lindisp ', args.lindisp, ' decay_iteration ', decay_iteration)"
#         },
#         {
#           "type": "call",
#           "content": "print('Random FROM SINGLE IMAGE')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013625888848
#         },
#         {
#           "type": "code",
#           "content": "# Random from one image\n        img_i = np.random.choice(i_train)\n\n        if i % (decay_iteration * 1000) == 0:\n            torch.cuda.empty_cache()\n\n        target = images[img_i].cuda()\n        pose = poses[img_i, :3,:4]\n        depth_gt = depths[img_i].cuda()\n\n        hard_coords = torch.Tensor(motion_coords[img_i]).cuda()\n        mask_gt = masks[img_i].cuda()\n\n\n        index=img_i//2\n\n        if index == 0:\n            index=img_i//2"
#         },
#         {
#           "type": "call",
#           "content": "flow_fwd, fwd_mask = read_optical_flow_NVDS(args.datadir, index,",
#           "callee": "run_nerf.read_optical_flow_NVDS",
#           "ast_id": 140013627787024
#         },
#         {
#           "type": "code",
#           "content": "args.start_frame, fwd=True)"
#         },
#         {
#           "type": "call",
#           "content": "flow_bwd, bwd_mask = np.zeros_like(flow_fwd), np.zeros_like(fwd_mask)",
#           "callee": "np.zeros_like",
#           "ast_id": 140013627793424
#         },
#         {
#           "type": "call",
#           "content": "flow_bwd, bwd_mask = np.zeros_like(flow_fwd), np.zeros_like(fwd_mask)",
#           "callee": "np.zeros_like",
#           "ast_id": 140013647338896
#         },
#         {
#           "type": "code",
#           "content": "elif index == num_img//2 - 1:\n            index=img_i//2"
#         },
#         {
#           "type": "call",
#           "content": "flow_bwd, bwd_mask = read_optical_flow_NVDS(args.datadir, index,",
#           "callee": "run_nerf.read_optical_flow_NVDS",
#           "ast_id": 140013647346128
#         },
#         {
#           "type": "code",
#           "content": "args.start_frame, fwd=False)"
#         },
#         {
#           "type": "call",
#           "content": "flow_fwd, fwd_mask = np.zeros_like(flow_bwd), np.zeros_like(bwd_mask)",
#           "callee": "np.zeros_like",
#           "ast_id": 140013647344592
#         },
#         {
#           "type": "call",
#           "content": "flow_fwd, fwd_mask = np.zeros_like(flow_bwd), np.zeros_like(bwd_mask)",
#           "callee": "np.zeros_like",
#           "ast_id": 140013647343120
#         },
#         {
#           "type": "code",
#           "content": "else:\n            index=img_i//2"
#         },
#         {
#           "type": "call",
#           "content": "flow_fwd, fwd_mask = read_optical_flow_NVDS(args.datadir,",
#           "callee": "run_nerf.read_optical_flow_NVDS",
#           "ast_id": 140013647339856
#         },
#         {
#           "type": "code",
#           "content": "index, args.start_frame, \n                                                fwd=True)"
#         },
#         {
#           "type": "call",
#           "content": "flow_bwd, bwd_mask = read_optical_flow_NVDS(args.datadir,",
#           "callee": "run_nerf.read_optical_flow_NVDS",
#           "ast_id": 140013647335440
#         },
#         {
#           "type": "code",
#           "content": "index, args.start_frame, \n                                                fwd=False)\n\n    \n        flow_fwd = torch.Tensor(flow_fwd).cuda()\n        fwd_mask = torch.Tensor(fwd_mask).cuda()\n    \n        flow_bwd = torch.Tensor(flow_bwd).cuda()\n        bwd_mask = torch.Tensor(bwd_mask).cuda()\n        # more correct way for flow loss\n        flow_fwd = flow_fwd + uv_grid\n        flow_bwd = flow_bwd + uv_grid\n\n        if N_rand is not None:"
#         },
#         {
#           "type": "call",
#           "content": "rays_o, rays_d = get_rays(H, W, focal, torch.Tensor(pose))  # (H, W, 3), (H, W, 3)",
#           "callee": "run_nerf.get_rays",
#           "ast_id": 140013647405584
#         },
#         {
#           "type": "call",
#           "content": "coords = torch.stack(torch.meshgrid(torch.linspace(0, H-1, H), torch.linspace(0, W-1, W)), -1)  # (H, W, 2)",
#           "callee": "torch.stack",
#           "ast_id": 140013646721360
#         },
#         {
#           "type": "call",
#           "content": "coords = torch.reshape(coords, [-1,2])  # (H * W, 2)",
#           "callee": "torch.reshape",
#           "ast_id": 140013647273488
#         },
#         {
#           "type": "code",
#           "content": "if args.use_motion_mask and i <= decay_iteration * 1000:"
#         },
#         {
#           "type": "call",
#           "content": "print('HARD MINING STAGE !')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013647281552
#         },
#         {
#           "type": "code",
#           "content": "num_extra_sample = args.num_extra_sample"
#         },
#         {
#           "type": "call",
#           "content": "print('num_extra_sample ', num_extra_sample)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013647278544
#         },
#         {
#           "type": "code",
#           "content": "select_inds_hard = np.random.choice(hard_coords.shape[0], \n                                                    size=[min(hard_coords.shape[0], \n                                                        num_extra_sample)], \n                                                    replace=False)  # (N_rand,)\n                select_inds_all = np.random.choice(coords.shape[0], \n                                                size=[N_rand], \n                                                replace=False)  # (N_rand,)\n\n                select_coords_hard = hard_coords[select_inds_hard].long()\n                select_coords_all = coords[select_inds_all].long()"
#         },
#         {
#           "type": "call",
#           "content": "select_coords = torch.cat([select_coords_all, select_coords_hard], 0)",
#           "callee": "torch.cat",
#           "ast_id": 140013646835216
#         },
#         {
#           "type": "code",
#           "content": "rays_o = rays_o[select_coords[:, 0], \n                            select_coords[:, 1]]  \n                rays_d = rays_d[select_coords[:, 0], \n                                select_coords[:, 1]]"
#         },
#         {
#           "type": "call",
#           "content": "batch_rays = torch.stack([rays_o, rays_d], 0)",
#           "callee": "torch.stack",
#           "ast_id": 140013646824848
#         },
#         {
#           "type": "code",
#           "content": "target_rgb = target[select_coords[:, 0], \n                                    select_coords[:, 1]]  \n                target_depth = depth_gt[select_coords[:, 0], \n                                    select_coords[:, 1]]\n                target_mask= mask_gt[select_coords[:, 0], \n                                    select_coords[:, 1]]\n\n                target_of_fwd = flow_fwd[select_coords[:, 0], \n                                        select_coords[:, 1]]\n                target_fwd_mask = fwd_mask[select_coords[:, 0], \n                                        select_coords[:, 1]].unsqueeze(-1)\n\n                target_of_bwd = flow_bwd[select_coords[:, 0], \n                                        select_coords[:, 1]]\n                target_bwd_mask = bwd_mask[select_coords[:, 0], \n                                        select_coords[:, 1]].unsqueeze(-1)\n\n            else:\n                if i>2*decay_iteration*1000:\n                    N_rand=384\n                else:\n                    N_rand=512\n                select_inds = np.random.choice(coords.shape[0], \n                                            size=[N_rand], \n                                            replace=False)  \n                select_coords = coords[select_inds].long()"
#         },
#         {
#           "type": "call",
#           "content": "xs, ys = np.meshgrid(np.arange(W, dtype=np.float32), np.arange(H, dtype=np.float32), indexing='xy')",
#           "callee": "np.meshgrid",
#           "ast_id": 140013624515728
#         },
#         {
#           "type": "call",
#           "content": "xs = np.tile((xs[...,None] + 0.5), [1, 1, 1])",
#           "callee": "np.tile",
#           "ast_id": 140013624522704
#         },
#         {
#           "type": "call",
#           "content": "ys = np.tile((ys[...,None] + 0.5), [1, 1, 1])",
#           "callee": "np.tile",
#           "ast_id": 140013624511312
#         },
#         {
#           "type": "call",
#           "content": "xs=np.reshape(xs,[-1,1])",
#           "callee": "np.reshape",
#           "ast_id": 140013646611536
#         },
#         {
#           "type": "call",
#           "content": "ys=np.reshape(ys,[-1,1])",
#           "callee": "np.reshape",
#           "ast_id": 140013646616080
#         },
#         {
#           "type": "code",
#           "content": "rays_x=xs[select_inds]\n                rays_y=ys[select_inds]\n                rays_x=torch.Tensor(rays_x).cuda()\n                rays_y=torch.Tensor(rays_y).cuda()\n                rays_o = rays_o[select_coords[:, 0], \n                                select_coords[:, 1]] \n                rays_d = rays_d[select_coords[:, 0], \n                                select_coords[:, 1]]"
#         },
#         {
#           "type": "call",
#           "content": "batch_rays = torch.stack([rays_o, rays_d], 0)",
#           "callee": "torch.stack",
#           "ast_id": 140013627654800
#         },
#         {
#           "type": "code",
#           "content": "target_rgb = target[select_coords[:, 0], \n                                    select_coords[:, 1]]  \n                target_depth = depth_gt[select_coords[:, 0], \n                                    select_coords[:, 1]]\n                target_mask= mask_gt[select_coords[:, 0], \n                                    select_coords[:, 1]]\n                target_of_fwd = flow_fwd[select_coords[:, 0], \n                                        select_coords[:, 1]]\n                target_fwd_mask = fwd_mask[select_coords[:, 0], \n                                        select_coords[:, 1]].unsqueeze(-1)\n\n                target_of_bwd = flow_bwd[select_coords[:, 0], \n                                        select_coords[:, 1]]\n                target_bwd_mask = bwd_mask[select_coords[:, 0], \n                                        select_coords[:, 1]].unsqueeze(-1)\n                \n            \n\n        img_idx_embed = img_i/num_img * 2. - 1.0\n\n        #####  Core optimization loop  #####\n        if args.chain_sf and i > decay_iteration * 1000 * 2:\n            chain_5frames = True\n        else:\n            chain_5frames = False"
#         },
#         {
#           "type": "call",
#           "content": "print('chain_5frames ', chain_5frames, ' chain_bwd ', chain_bwd)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013624118608
#         },
#         {
#           "type": "code",
#           "content": "if i <= decay_iteration * 1000:"
#         },
#         {
#           "type": "call",
#           "content": "ret = render(img_idx_embed,",
#           "callee": "run_nerf.render",
#           "ast_id": 140013625219152
#         },
#         {
#           "type": "code",
#           "content": "chain_bwd, \n                     chain_5frames,\n                     num_img, H, W, focal, \n                     chunk=args.chunk, \n                     rays=batch_rays,\n                     verbose=i < 10, retraw=True,\n                     **render_kwargs_train)\n    \n        else:"
#         },
#         {
#           "type": "call",
#           "content": "new_rays, weight,align_loss = kernelnet(H, W, K, batch_rays,img_idx_embed,index, rays_x,rays_y)",
#           "callee": "run_nerf.kernelnet",
#           "ast_id": 140013625219216
#         },
#         {
#           "type": "code",
#           "content": "ray_num, pt_num = new_rays.shape[1:3]"
#         },
#         {
#           "type": "call",
#           "content": "ret_rgb= render_mpi_dsk(img_idx_embed,",
#           "callee": "run_nerf.render_mpi_dsk",
#           "ast_id": 140013625221968
#         },
#         {
#           "type": "code",
#           "content": "chain_bwd, \n                chain_5frames,\n                num_img, H, W, focal, \n                chunk=args.chunk, \n                rays=new_rays.reshape(2,-1,3),\n                verbose=i < 10, retraw=True,weight=weight,num_pt=num_pt,\n                **render_kwargs_train)"
#         },
#         {
#           "type": "call",
#           "content": "ret= render(img_idx_embed,",
#           "callee": "run_nerf.render",
#           "ast_id": 140013625215440
#         },
#         {
#           "type": "code",
#           "content": "chain_bwd, \n                chain_5frames,\n                num_img, H, W, focal, \n                chunk=args.chunk, \n                rays=batch_rays,\n                verbose=i < 10, retraw=True,\n                **render_kwargs_train)"
#         },
#         {
#           "type": "call",
#           "content": "pose_post = poses[min(img_i + 1, int(num_img) - 1), :3,:4]",
#           "callee": "run_nerf.min",
#           "ast_id": 140013624862032
#         },
#         {
#           "type": "call",
#           "content": "pose_prev = poses[max(img_i - 1, 0), :3,:4]",
#           "callee": "run_nerf.max",
#           "ast_id": 140013624854160
#         },
#         {
#           "type": "call",
#           "content": "render_of_fwd, render_of_bwd = compute_optical_flow(pose_post,",
#           "callee": "run_nerf.compute_optical_flow",
#           "ast_id": 140013624863376
#         },
#         {
#           "type": "code",
#           "content": "pose, pose_prev, \n                                                            H, W, focal, \n                                                            ret)"
#         },
#         {
#           "type": "call",
#           "content": "optimizer.zero_grad()",
#           "callee": "optimizer.zero_grad",
#           "ast_id": 140013624862416
#         },
#         {
#           "type": "code",
#           "content": "weight_map_post = ret['prob_map_post']\n        weight_map_prev = ret['prob_map_prev']\n\n        weight_post = 1. - ret['raw_prob_ref2post']\n        weight_prev = 1. - ret['raw_prob_ref2prev']"
#         },
#         {
#           "type": "call",
#           "content": "prob_reg_loss = args.w_prob_reg * (torch.mean(torch.abs(ret['raw_prob_ref2prev'])) \\",
#           "callee": "torch.mean",
#           "ast_id": 140013624863440
#         },
#         {
#           "type": "call",
#           "content": "+ torch.mean(torch.abs(ret['raw_prob_ref2post'])))",
#           "callee": "torch.mean",
#           "ast_id": 140013624859856
#         },
#         {
#           "type": "code",
#           "content": "if i <= decay_iteration * 1000:\n            rgb_dy=ret['rgb_map_ref_dy']\n            rgb_post_dy=ret['rgb_map_post_dy']\n            rgb_prev_dy=ret['rgb_map_prev_dy']\n            rgb_ref=ret['rgb_map_ref']\n            if chain_5frames:\n                rgb_map_pp_dy=ret['rgb_map_pp_dy']\n        else:\n\n            rgb_dy=ret_rgb['bokeh_map_ref_dy']\n            rgb_post_dy=ret_rgb['bokeh_map_post_dy']\n            rgb_prev_dy=ret_rgb['bokeh_map_prev_dy']\n            rgb_ref=ret_rgb['bokeh_map_ref']\n            if chain_5frames:\n                rgb_map_pp_dy=ret_rgb['bokeh_map_pp_dy']\n\n\n        # dynamic rendering loss\n        if i <= decay_iteration * 1000:"
#         },
#         {
#           "type": "call",
#           "content": "render_loss = img2mse(rgb_dy, target_rgb)",
#           "callee": "run_nerf.img2mse",
#           "ast_id": 140013624005456
#         },
#         {
#           "type": "call",
#           "content": "render_loss += compute_mse(rgb_post_dy,",
#           "callee": "run_nerf.compute_mse",
#           "ast_id": 140013624004560
#         },
#         {
#           "type": "code",
#           "content": "target_rgb, \n                                       weight_map_post.unsqueeze(-1))"
#         },
#         {
#           "type": "call",
#           "content": "render_loss += compute_mse(rgb_prev_dy,",
#           "callee": "run_nerf.compute_mse",
#           "ast_id": 140013623938000
#         },
#         {
#           "type": "code",
#           "content": "target_rgb, \n                                       weight_map_prev.unsqueeze(-1))\n        else:"
#         },
#         {
#           "type": "call",
#           "content": "print('only compute dynamic render loss in masked region')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013623936208
#         },
#         {
#           "type": "code",
#           "content": "weights_map_dd = ret['weights_map_dd'].unsqueeze(-1).detach()"
#         },
#         {
#           "type": "call",
#           "content": "render_loss = compute_mse(rgb_dy,",
#           "callee": "run_nerf.compute_mse",
#           "ast_id": 140013623939088
#         },
#         {
#           "type": "code",
#           "content": "target_rgb, \n                                      weights_map_dd)"
#         },
#         {
#           "type": "call",
#           "content": "render_loss += compute_mse(rgb_post_dy,",
#           "callee": "run_nerf.compute_mse",
#           "ast_id": 140013623941968
#         },
#         {
#           "type": "code",
#           "content": "target_rgb, \n                                       weight_map_post.unsqueeze(-1) * weights_map_dd)"
#         },
#         {
#           "type": "call",
#           "content": "render_loss += compute_mse(rgb_prev_dy,",
#           "callee": "run_nerf.compute_mse",
#           "ast_id": 140013623942992
#         },
#         {
#           "type": "code",
#           "content": "target_rgb, \n                                       weight_map_prev.unsqueeze(-1) * weights_map_dd)\n\n            \n        target_mask=target_mask+1e-5"
#         },
#         {
#           "type": "call",
#           "content": "render_loss += img2mse(rgb_ref[:N_rand, ...],",
#           "callee": "run_nerf.img2mse",
#           "ast_id": 140013623948112
#         },
#         {
#           "type": "code",
#           "content": "target_rgb[:N_rand, ...])\n        if i<N_iters*0.8:\n            if i >decay_iteration * 1000:\n                render_loss += 0.1*align_loss"
#         },
#         {
#           "type": "call",
#           "content": "sf_cycle_loss = args.w_cycle * compute_mae(ret['raw_sf_ref2post'],",
#           "callee": "run_nerf.compute_mae",
#           "ast_id": 140013623947728
#         },
#         {
#           "type": "code",
#           "content": "-ret['raw_sf_post2ref'], \n                                                   weight_post.unsqueeze(-1), dim=3)"
#         },
#         {
#           "type": "call",
#           "content": "sf_cycle_loss += args.w_cycle * compute_mae(ret['raw_sf_ref2prev'],",
#           "callee": "run_nerf.compute_mae",
#           "ast_id": 140013624369616
#         },
#         {
#           "type": "code",
#           "content": "-ret['raw_sf_prev2ref'], \n                                                    weight_prev.unsqueeze(-1), dim=3)\n        \n        # regularization loss"
#         },
#         {
#           "type": "call",
#           "content": "render_sf_ref2prev = torch.sum(ret['weights_ref_dy'].unsqueeze(-1) * ret['raw_sf_ref2prev'], -1)",
#           "callee": "torch.sum",
#           "ast_id": 140013624365200
#         },
#         {
#           "type": "call",
#           "content": "render_sf_ref2post = torch.sum(ret['weights_ref_dy'].unsqueeze(-1) * ret['raw_sf_ref2post'], -1)",
#           "callee": "torch.sum",
#           "ast_id": 140013624365904
#         },
#         {
#           "type": "call",
#           "content": "sf_reg_loss = args.w_sf_reg * (torch.mean(torch.abs(render_sf_ref2prev)) \\",
#           "callee": "torch.mean",
#           "ast_id": 140013624371984
#         },
#         {
#           "type": "call",
#           "content": "+ torch.mean(torch.abs(render_sf_ref2post)))",
#           "callee": "torch.mean",
#           "ast_id": 140013624371280
#         },
#         {
#           "type": "code",
#           "content": "divsor = i // (decay_iteration * 1000)\n\n        decay_rate = 10\n\n        if args.decay_depth_w:\n            w_depth = args.w_depth/(decay_rate ** divsor)\n        else:\n            w_depth = args.w_depth\n\n        if args.decay_optical_flow_w:\n            w_of = args.w_optical_flow/(decay_rate ** divsor)\n        else:\n            w_of = args.w_optical_flow"
#         },
#         {
#           "type": "call",
#           "content": "depth_loss = w_depth * (compute_depth_loss(ret['depth_map_ref_dy'], -target_depth))",
#           "callee": "run_nerf.compute_depth_loss",
#           "ast_id": 140013623363792
#         },
#         {
#           "type": "call",
#           "content": "print('w_depth ', w_depth, 'w_of ', w_of)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013623368016
#         },
#         {
#           "type": "code",
#           "content": "if index == 0:"
#         },
#         {
#           "type": "call",
#           "content": "print('only fwd flow')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013623377296
#         },
#         {
#           "type": "call",
#           "content": "flow_loss = w_of * compute_mae(render_of_fwd,",
#           "callee": "run_nerf.compute_mae",
#           "ast_id": 140013623363216
#         },
#         {
#           "type": "code",
#           "content": "target_of_fwd, \n                                        target_fwd_mask)#torch.sum(torch.abs(render_of_fwd - target_of_fwd) * target_fwd_mask)/(torch.sum(target_fwd_mask) + 1e-8)\n        elif index == num_img//2 - 1:"
#         },
#         {
#           "type": "call",
#           "content": "print('only bwd flow')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013623366928
#         },
#         {
#           "type": "call",
#           "content": "flow_loss = w_of * compute_mae(render_of_bwd,",
#           "callee": "run_nerf.compute_mae",
#           "ast_id": 140013623362768
#         },
#         {
#           "type": "code",
#           "content": "target_of_bwd, \n                                        target_bwd_mask)#torch.sum(torch.abs(render_of_bwd - target_of_bwd) * target_bwd_mask)/(torch.sum(target_bwd_mask) + 1e-8)\n        else:"
#         },
#         {
#           "type": "call",
#           "content": "flow_loss = w_of * compute_mae(render_of_fwd,",
#           "callee": "run_nerf.compute_mae",
#           "ast_id": 140013623369232
#         },
#         {
#           "type": "code",
#           "content": "target_of_fwd, \n                                        target_fwd_mask)#torch.sum(torch.abs(render_of_fwd - target_of_fwd) * target_fwd_mask)/(torch.sum(target_fwd_mask) + 1e-8)"
#         },
#         {
#           "type": "call",
#           "content": "flow_loss += w_of * compute_mae(render_of_bwd,",
#           "callee": "run_nerf.compute_mae",
#           "ast_id": 140013623377104
#         },
#         {
#           "type": "code",
#           "content": "target_of_bwd, \n                                        target_bwd_mask)#torch.sum(torch.abs(render_of_bwd - target_of_bwd) * target_bwd_mask)/(torch.sum(target_bwd_mask) + 1e-8)\n\n        # scene flow smoothness loss"
#         },
#         {
#           "type": "call",
#           "content": "sf_sm_loss = args.w_sm * (compute_sf_sm_loss(ret['raw_pts_ref'],",
#           "callee": "run_nerf.compute_sf_sm_loss",
#           "ast_id": 140013623377168
#         },
#         {
#           "type": "code",
#           "content": "ret['raw_pts_post'], \n                                                    H, W, focal) \\"
#         },
#         {
#           "type": "call",
#           "content": "+ compute_sf_sm_loss(ret['raw_pts_ref'],",
#           "callee": "run_nerf.compute_sf_sm_loss",
#           "ast_id": 140013623081936
#         },
#         {
#           "type": "code",
#           "content": "ret['raw_pts_prev'], \n                                                    H, W, focal))\n\n        # scene flow least kinectic loss"
#         },
#         {
#           "type": "call",
#           "content": "sf_sm_loss += args.w_sm * compute_sf_lke_loss(ret['raw_pts_ref'],",
#           "callee": "run_nerf.compute_sf_lke_loss",
#           "ast_id": 140013623082512
#         },
#         {
#           "type": "code",
#           "content": "ret['raw_pts_post'], \n                                                    ret['raw_pts_prev'], \n                                                    H, W, focal)"
#         },
#         {
#           "type": "call",
#           "content": "sf_sm_loss += args.w_sm * compute_sf_lke_loss(ret['raw_pts_ref'],",
#           "callee": "run_nerf.compute_sf_lke_loss",
#           "ast_id": 140013623074256
#         },
#         {
#           "type": "code",
#           "content": "ret['raw_pts_post'], \n                                                    ret['raw_pts_prev'], \n                                                    H, W, focal)"
#         },
#         {
#           "type": "call",
#           "content": "entropy_loss = args.w_entropy * torch.mean(-ret['raw_blend_w'] * torch.log(ret['raw_blend_w'] + 1e-8))",
#           "callee": "torch.mean",
#           "ast_id": 140013623072656
#         },
#         {
#           "type": "code",
#           "content": "# # ======================================  two-frames chain loss ===============================\n        if chain_bwd:"
#         },
#         {
#           "type": "call",
#           "content": "sf_sm_loss += args.w_sm * compute_sf_lke_loss(ret['raw_pts_prev'],",
#           "callee": "run_nerf.compute_sf_lke_loss",
#           "ast_id": 140013626185872
#         },
#         {
#           "type": "code",
#           "content": "ret['raw_pts_ref'], \n                                                          ret['raw_pts_pp'], \n                                                          H, W, focal)\n\n        else:"
#         },
#         {
#           "type": "call",
#           "content": "sf_sm_loss += args.w_sm * compute_sf_lke_loss(ret['raw_pts_post'],",
#           "callee": "run_nerf.compute_sf_lke_loss",
#           "ast_id": 140013626186384
#         },
#         {
#           "type": "code",
#           "content": "ret['raw_pts_pp'], \n                                                          ret['raw_pts_ref'], \n                                                          H, W, focal)\n\n        if chain_5frames:"
#         },
#         {
#           "type": "call",
#           "content": "render_loss += compute_mse(rgb_map_pp_dy,",
#           "callee": "run_nerf.compute_mse",
#           "ast_id": 140013626191376
#         },
#         {
#           "type": "code",
#           "content": "target_rgb, \n                                weights_map_dd)\n\n\n        loss = sf_reg_loss + sf_cycle_loss + \\\n               render_loss + flow_loss + \\\n               sf_sm_loss + prob_reg_loss + \\\n               depth_loss + entropy_loss"
#         },
#         {
#           "type": "call",
#           "content": "print('render_loss ', render_loss.item(),",
#           "callee": "run_nerf.print",
#           "ast_id": 140013626183888
#         },
#         {
#           "type": "code",
#           "content": "' bidirection_loss ', sf_cycle_loss.item(), \n              ' sf_reg_loss ', sf_reg_loss.item())"
#         },
#         {
#           "type": "call",
#           "content": "print('depth_loss ', depth_loss.item(),",
#           "callee": "run_nerf.print",
#           "ast_id": 140013626191568
#         },
#         {
#           "type": "code",
#           "content": "' flow_loss ', flow_loss.item(), \n              ' sf_sm_loss ', sf_sm_loss.item())"
#         },
#         {
#           "type": "call",
#           "content": "print('prob_reg_loss ', prob_reg_loss.item(),",
#           "callee": "run_nerf.print",
#           "ast_id": 140013626191184
#         },
#         {
#           "type": "code",
#           "content": "' entropy_loss ', entropy_loss.item())\n        # with torch.autograd.detect_anomaly():"
#         },
#         {
#           "type": "call",
#           "content": "loss.backward()",
#           "callee": "loss.backward",
#           "ast_id": 140013647069648
#         },
#         {
#           "type": "call",
#           "content": "optimizer.step()",
#           "callee": "optimizer.step",
#           "ast_id": 140013647084112
#         },
#         {
#           "type": "code",
#           "content": "# NOTE: IMPORTANT!\n        ###   update learning rate   ###\n        decay_rate = 0.1\n        decay_steps = args.lrate_decay * 1000\n        new_lrate = args.lrate * (decay_rate ** (global_step / decay_steps))\n        for param_group in optimizer.param_groups:\n            param_group['lr'] = new_lrate\n        ################################"
#         },
#         {
#           "type": "call",
#           "content": "dt = time.time()-time0",
#           "callee": "time.time",
#           "ast_id": 140013647074960
#         },
#         {
#           "type": "call",
#           "content": "print(f\"Step: {global_step}, Loss: {loss}, Time: {dt}\")",
#           "callee": "run_nerf.print",
#           "ast_id": 140013647077968
#         },
#         {
#           "type": "code",
#           "content": "#####           end            #####\n\n        # Rest is logging\n        if i%args.i_weights==0:\n            path = os.path.join(basedir, expname, '{:06d}.tar'.format(i))\n\n            if args.N_importance > 0:"
#         },
#         {
#           "type": "call",
#           "content": "torch.save({",
#           "callee": "torch.save",
#           "ast_id": 140013647072976
#         },
#         {
#           "type": "code",
#           "content": "'global_step': global_step,\n                    'network_fn_state_dict': render_kwargs_train['network_fn'].state_dict(),\n                    'network_rigid': render_kwargs_train['network_rigid'].state_dict(),\n                    'optimizer_state_dict': optimizer.state_dict(),\n                    'kernel_state_dict': kernelnet.state_dict(),\n                }, path)\n            \n            else:"
#         },
#         {
#           "type": "call",
#           "content": "torch.save({",
#           "callee": "torch.save",
#           "ast_id": 140013623701648
#         },
#         {
#           "type": "code",
#           "content": "'global_step': global_step,\n                    'network_fn_state_dict': render_kwargs_train['network_fn'].state_dict(),\n                    'network_rigid': render_kwargs_train['network_rigid'].state_dict(),\n                    'optimizer_state_dict': optimizer.state_dict(),\n                    'kernel_state_dict': kernelnet.state_dict(),\n                }, path)"
#         },
#         {
#           "type": "call",
#           "content": "print('Saved checkpoints at', path)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013623693328
#         },
#         {
#           "type": "code",
#           "content": "if i % args.i_print == 0 and i > 0:"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_scalar(\"train/loss\", loss.item(), i)",
#           "callee": "writer.add_scalar",
#           "ast_id": 140013623703696
#         },
#         {
#           "type": "call",
#           "content": "writer.add_scalar(\"train/render_loss\", render_loss.item(), i)",
#           "callee": "writer.add_scalar",
#           "ast_id": 140013623698192
#         },
#         {
#           "type": "call",
#           "content": "writer.add_scalar(\"train/depth_loss\", depth_loss.item(), i)",
#           "callee": "writer.add_scalar",
#           "ast_id": 140013623695952
#         },
#         {
#           "type": "call",
#           "content": "writer.add_scalar(\"train/flow_loss\", flow_loss.item(), i)",
#           "callee": "writer.add_scalar",
#           "ast_id": 140013646860752
#         },
#         {
#           "type": "call",
#           "content": "writer.add_scalar(\"train/prob_reg_loss\", prob_reg_loss.item(), i)",
#           "callee": "writer.add_scalar",
#           "ast_id": 140013646863248
#         },
#         {
#           "type": "call",
#           "content": "writer.add_scalar(\"train/sf_reg_loss\", sf_reg_loss.item(), i)",
#           "callee": "writer.add_scalar",
#           "ast_id": 140013646861136
#         },
#         {
#           "type": "call",
#           "content": "writer.add_scalar(\"train/sf_cycle_loss\", sf_cycle_loss.item(), i)",
#           "callee": "writer.add_scalar",
#           "ast_id": 140013646862992
#         },
#         {
#           "type": "call",
#           "content": "writer.add_scalar(\"train/sf_sm_loss\", sf_sm_loss.item(), i)",
#           "callee": "writer.add_scalar",
#           "ast_id": 140013624256080
#         },
#         {
#           "type": "code",
#           "content": "if i%args.i_img == 0:\n            target = images[img_i]\n            pose = poses[img_i, :3,:4]"
#         },
#         {
#           "type": "call",
#           "content": "target_depth = depths[img_i] - torch.min(depths[img_i])",
#           "callee": "torch.min",
#           "ast_id": 140013624258832
#         },
#         {
#           "type": "call",
#           "content": "target_mask= masks[img_i] - torch.min(masks[img_i])",
#           "callee": "torch.min",
#           "ast_id": 140013624252176
#         },
#         {
#           "type": "code",
#           "content": "img_idx_embed = img_i/num_img * 2. - 1.0\n            index=img_i//2\n            if index == 0:"
#         },
#         {
#           "type": "call",
#           "content": "flow_fwd, fwd_mask = read_optical_flow_NVDS(args.datadir, index,",
#           "callee": "run_nerf.read_optical_flow_NVDS",
#           "ast_id": 140013624254864
#         },
#         {
#           "type": "code",
#           "content": "args.start_frame, fwd=True)"
#         },
#         {
#           "type": "call",
#           "content": "flow_bwd, bwd_mask = np.zeros_like(flow_fwd), np.zeros_like(fwd_mask)",
#           "callee": "np.zeros_like",
#           "ast_id": 140013624251728
#         },
#         {
#           "type": "call",
#           "content": "flow_bwd, bwd_mask = np.zeros_like(flow_fwd), np.zeros_like(fwd_mask)",
#           "callee": "np.zeros_like",
#           "ast_id": 140013624332048
#         },
#         {
#           "type": "code",
#           "content": "elif index == num_img//2 - 1:"
#         },
#         {
#           "type": "call",
#           "content": "flow_bwd, bwd_mask = read_optical_flow_NVDS(args.datadir, index,",
#           "callee": "run_nerf.read_optical_flow_NVDS",
#           "ast_id": 140013624328400
#         },
#         {
#           "type": "code",
#           "content": "args.start_frame, fwd=False)"
#         },
#         {
#           "type": "call",
#           "content": "flow_fwd, fwd_mask = np.zeros_like(flow_bwd), np.zeros_like(bwd_mask)",
#           "callee": "np.zeros_like",
#           "ast_id": 140013624342352
#         },
#         {
#           "type": "call",
#           "content": "flow_fwd, fwd_mask = np.zeros_like(flow_bwd), np.zeros_like(bwd_mask)",
#           "callee": "np.zeros_like",
#           "ast_id": 140013624329168
#         },
#         {
#           "type": "code",
#           "content": "else:"
#         },
#         {
#           "type": "call",
#           "content": "flow_fwd, fwd_mask = read_optical_flow_NVDS(args.datadir,",
#           "callee": "run_nerf.read_optical_flow_NVDS",
#           "ast_id": 140013624336656
#         },
#         {
#           "type": "code",
#           "content": "index, args.start_frame, \n                                                       fwd=True)"
#         },
#         {
#           "type": "call",
#           "content": "flow_bwd, bwd_mask = read_optical_flow_NVDS(args.datadir,",
#           "callee": "run_nerf.read_optical_flow_NVDS",
#           "ast_id": 140013624338064
#         },
#         {
#           "type": "code",
#           "content": "index, args.start_frame, \n                                                       fwd=False)"
#         },
#         {
#           "type": "call",
#           "content": "flow_fwd_rgb = torch.Tensor(flow_to_image(flow_fwd)/255.)#.cuda()",
#           "callee": "torch.Tensor",
#           "ast_id": 140013622930768
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/gt_flow_fwd\",",
#           "callee": "writer.add_image",
#           "ast_id": 140013622928592
#         },
#         {
#           "type": "code",
#           "content": "flow_fwd_rgb, global_step=i, dataformats='HWC')"
#         },
#         {
#           "type": "call",
#           "content": "flow_bwd_rgb = torch.Tensor(flow_to_image(flow_bwd)/255.)#.cuda()",
#           "callee": "torch.Tensor",
#           "ast_id": 140013622919376
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/gt_flow_bwd\",",
#           "callee": "writer.add_image",
#           "ast_id": 140013622925392
#         },
#         {
#           "type": "code",
#           "content": "flow_bwd_rgb, global_step=i, dataformats='HWC')"
#         },
#         {
#           "type": "call",
#           "content": "with torch.no_grad():",
#           "callee": "torch.no_grad",
#           "ast_id": 140013622926224
#         },
#         {
#           "type": "call",
#           "content": "ret = render(img_idx_embed,",
#           "callee": "run_nerf.render",
#           "ast_id": 140013622924112
#         },
#         {
#           "type": "code",
#           "content": "chain_bwd, False,\n                        num_img, H, W, focal, \n                        chunk=1024*16, \n                        c2w=pose,\n                        **render_kwargs_test)"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/rgb_map_ref\", torch.clamp(ret['rgb_map_ref'], 0., 1.),",
#           "callee": "writer.add_image",
#           "ast_id": 140013622934160
#         },
#         {
#           "type": "code",
#           "content": "global_step=i, dataformats='HWC')"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/depth_map_ref\", normalize_depth(ret['depth_map_ref']),",
#           "callee": "writer.add_image",
#           "ast_id": 140013622932304
#         },
#         {
#           "type": "code",
#           "content": "global_step=i, dataformats='HW')"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/rgb_map_rig\", torch.clamp(ret['rgb_map_rig'], 0., 1.),",
#           "callee": "writer.add_image",
#           "ast_id": 140013625091984
#         },
#         {
#           "type": "code",
#           "content": "global_step=i, dataformats='HWC')"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/depth_map_rig\", normalize_depth(ret['depth_map_rig']),",
#           "callee": "writer.add_image",
#           "ast_id": 140013625083920
#         },
#         {
#           "type": "code",
#           "content": "global_step=i, dataformats='HW')"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/rgb_map_ref_dy\", torch.clamp(ret['rgb_map_ref_dy'], 0., 1.),",
#           "callee": "writer.add_image",
#           "ast_id": 140013625082320
#         },
#         {
#           "type": "code",
#           "content": "global_step=i, dataformats='HWC')"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/depth_map_ref_dy\", normalize_depth(ret['depth_map_ref_dy']),",
#           "callee": "writer.add_image",
#           "ast_id": 140013625084112
#         },
#         {
#           "type": "code",
#           "content": "global_step=i, dataformats='HW')"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/gt_rgb\", target,",
#           "callee": "writer.add_image",
#           "ast_id": 140013625088144
#         },
#         {
#           "type": "code",
#           "content": "global_step=i, dataformats='HWC')"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/monocular_disp\",",
#           "callee": "writer.add_image",
#           "ast_id": 140013625097744
#         },
#         {
#           "type": "code",
#           "content": "torch.clamp(target_depth /percentile(target_depth, 97), 0., 1.), \n                                global_step=i, dataformats='HW')"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/mask_rig\",",
#           "callee": "writer.add_image",
#           "ast_id": 140013625097552
#         },
#         {
#           "type": "code",
#           "content": "torch.clamp(target_mask /percentile(target_mask, 97), 0., 1.), \n                                global_step=i, dataformats='HW')"
#         },
#         {
#           "type": "call",
#           "content": "writer.add_image(\"val/weights_map_dd\",",
#           "callee": "writer.add_image",
#           "ast_id": 140013623551824
#         },
#         {
#           "type": "code",
#           "content": "ret['weights_map_dd'], \n                                 global_step=i, \n                                 dataformats='HW')\n\n            # torch.cuda.empty_cache()\n\n        if i%args.i_testset==0 and i > 0:"
#         },
#         {
#           "type": "call",
#           "content": "print('test poses shape', poses[i_test].shape)",
#           "callee": "run_nerf.print",
#           "ast_id": 140013623546192
#         },
#         {
#           "type": "code",
#           "content": "for img_i in i_test:\n                target = images[img_i]\n                pose = poses[img_i, :3,:4]"
#         },
#         {
#           "type": "call",
#           "content": "target_depth = depths[img_i] - torch.min(depths[img_i])",
#           "callee": "torch.min",
#           "ast_id": 140013623551568
#         },
#         {
#           "type": "code",
#           "content": "img_idx_embed = img_i/num_img * 2. - 1.0\n                testsavedir = os.path.join(basedir, expname, 'testset_{:06d}'.format(i))"
#         },
#         {
#           "type": "call",
#           "content": "os.makedirs(testsavedir, exist_ok=True)",
#           "callee": "os.makedirs",
#           "ast_id": 140013623545808
#         },
#         {
#           "type": "call",
#           "content": "with torch.no_grad():",
#           "callee": "torch.no_grad",
#           "ast_id": 140013623548944
#         },
#         {
#           "type": "call",
#           "content": "ret = render(img_idx_embed,",
#           "callee": "run_nerf.render",
#           "ast_id": 140013624057040
#         },
#         {
#           "type": "code",
#           "content": "chain_bwd, False,\n                            num_img, H, W, focal, \n                            chunk=1024*16, \n                            c2w=pose,\n                            **render_kwargs_test)\n                    rgb = ret['rgb_map_ref'].cpu().numpy()\n\n                    \n                    save_img_path = os.path.join(testsavedir, \n                                        '%06d_right.png'%((img_i-1)//2))"
#         },
#         {
#           "type": "call",
#           "content": "imageio.imwrite(save_img_path,",
#           "callee": "imageio.imwrite",
#           "ast_id": 140013624063760
#         },
#         {
#           "type": "code",
#           "content": "to8b(rgb))"
#         },
#         {
#           "type": "call",
#           "content": "print('Saved test set')",
#           "callee": "run_nerf.print",
#           "ast_id": 140013624064336
#         },
#         {
#           "type": "code",
#           "content": "global_step += 1"
#         }
#       ]
#     }
#   ]
# }
